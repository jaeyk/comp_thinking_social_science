# %% [markdown]
# # Accessing Databases via Web APIs: Lecture Code
# * * * * *
#
# Aside from Rochell's tutorial, I added some materials from [Python for  everybody](http://oskicat.berkeley.edu/search~S1?/Xweb+scraping+python&searchscope=1&SORT=D/Xweb+scraping+python&searchscope=1&SORT=D&SUBKEY=web+scraping+python/1%2C9%2C9%2CB/frameset&FF=Xweb+scraping+python&searchscope=1&SORT=D&9%2C9%2C) by Severance and [Web scraping with Python](http://oskicat.berkeley.edu/search~S1?/Xweb+scraping+python&searchscope=1&SORT=D/Xweb+scraping+python&searchscope=1&SORT=D&SUBKEY=web+scraping+python/1%2C9%2C9%2CB/frameset&FF=Xweb+scraping+python&searchscope=1&SORT=D&1%2C1%2C) by Mitchell.

# %%
# Import libraries
import requests
import urllib 
import json
import math
import ssl
import time

# %% [markdown]
# ## 1. Constructing API GET Request
#
# API (Application Program Interfaces) is basically a "contract" between one application to another. When we use an API, generally one programs (in this case, "New York Times") makes a set of services available for use by other applications and publishes the APIs (i.e., the "rules") that must be followed to access the services provided by the program.
#
# You need an API key to make use of a vendor's API. The vendor wants to know who is using their services and **how much** each user is using. Usually, they have a policy to make you pay for your use or limit the number of requests you can make during a particular time period (i.e., a day).
#
# The workflow is as follows. Every call will require us to provide a) a base URL for the API, b) some authorization code or key, and c) a format for the response.
#
# * Web scraping is a more general data collection technique than using API. Web scraping is when we write a program that pretends to be a web browser and retrieves pages, then examines the data in those pages looking for patterns. Using API is in most cases easier, faster, and legally more safe than web scraping.
#
# * There's a New York Time library called nytimes. But don't use that library since we aim to learn general skills that can be applied to any API step-by-step. Also, you should not use nytimes or any other similar libraries for doing the API group assignment.

# %%
# set key
key="lJWFqmFXKLE8yoxN95xLjnyqMFk67a5I" # Please use your API key.

# set base url
base_url="http://api.nytimes.com/svc/search/v2/articlesearch"

# set response format
response_format=".json"

# %% [markdown]
# You often want to send some sort of data in the URL’s query string. This data tells the API what information you want. In our case, we want articles about Prince. Requests allows you to provide these arguments as a dictionary, using the `params` keyword argument. In addition to the search term `q`, we have to put in the `api-key` term.
#
# ![How dictionary Works](https://developers.google.com/edu/python/images/dict.png)

# %%
# set search parameters
search_params = {"q":"Prince",
                 "api-key":key}

# %% [markdown]
# Now we're ready to make the request. We use the `.get` method from the `requests` library to make an HTTP GET Request.

# %%
# make request
nyt_response = requests.get(base_url + response_format, params = search_params)

# %% [markdown]
# Now, we have a [response](http://docs.python-requests.org/en/latest/api/#requests.Response) object called `r`. We can get all the information we need from this object. For instance, we can see that the URL has been correctly encoded by printing the URL. Click on the link to see what happens.

# %%
print(nyt_response.url)
# Out:
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=Prince&api-key=lJWFqmFXKLE8yoxN95xLjnyqMFk67a5I

# %% [markdown]
# Click on that link to see what it returns!

# %% [markdown]
# Hmm - looks like we're getting a lot of junk unrelated to the musical artist in here. Let's make it a little more specific:

# %%
# set search parameters
search_params = {"q":"Prince music",
                 "api-key":key}  
# make request
nyt_response = requests.get(base_url + response_format, params=search_params)

print(nyt_response.url)
# Out:
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=Prince+music&api-key=lJWFqmFXKLE8yoxN95xLjnyqMFk67a5I

# %% [markdown]
# Better!

# %% [markdown]
# ### Challenge 1:  Adding a date range
#
# What if we only want to search within a particular date range? The NYT Article API allows us to specify start and end dates.
#
# Alter the `search_params` code above so that the request only searches for articles in the year 2019.
#
# You're gonna need to look at the documentation [here](http://developer.nytimes.com/docs/read/article_search_api_v2) to see how to do this.

# %%
#YOUR CODE HERE

# Uncomment to test
# nyt_response = requests.get(base_url+response_format, params=search_params)
# nyt_response.url

# %% [markdown]
# ### Challenge 2:  Specifying a results page
#
# The above will return the first 10 results. To get the next ten, you need to add a "page" parameter. Change the search parameters above to get the second 10 resuls.

# %%
search_params = {"q":"Prince music",
                 "begin_date": "20190101",
                 "end_date": "20191231",
                 "page": "1",
                 "api-key":key}  
# make request
nyt_response = requests.get(base_url+response_format, params=search_params)

print(nyt_response.url)

# Uncomment to test
# r = requests.get(base_url+response_format, params=search_params)
# r.url
# Out:
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=Prince+music&begin_date=20190101&end_date=20191231&page=1&api-key=lJWFqmFXKLE8yoxN95xLjnyqMFk67a5I

# %% [markdown]
# ## 2. Parsing the response text

# %% [markdown]
# Simply put, parsing means making something complex understandable by analyzing its parts (see this [Quora entry](https://www.quora.com/What-exactly-does-parsing-mean-in-programming)).
#
# We can read the content of the server’s response using `.text`

# %%
# Inspect the content of the response, parsing the result as text
response_text= nyt_response.text

# Remember string is a sequence of characters.
# So, the result will display 1,000 characters.
print(response_text[:1000])
# Out:
# {"status":"OK","copyright":"Copyright (c) 2019 The New York Times Company. All Rights Reserved.","response":{"docs":[{"web_url":"https://www.nytimes.com/2019/02/10/arts/music/grammy-awards.html","snippet":"At a ceremony dominated by female performers and presenters, Musgraves won album of the year for “Golden Hour,” as well as three other awards.","lead_paragraph":"At a ceremony dominated by female performers and presenters, Musgraves won album of the year for “Golden Hour,” as well as three other awards.","print_page":"1","blog":{},"source":"The New York Times","multimedia":[{"rank":0,"subtype":"xlarge","caption":null,"credit":null,"type":"image","url":"images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-articleLarge.jpg","height":404,"width":600,"legacy":{"xlarge":"images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-articleLarge.jpg","xlargewidth":600,"xlargeheight":404},"subType":"xlarge","cr

# %% [markdown]
# What you see here is JSON text, encoded as unicode text. JSON stands for "Javascript object notation." It has a very similar structure to a python dictionary -- both are built on key/value pairs. This makes it easy to convert JSON response to a python dictionary.

# %%
# Convert JSON response to a dictionary

data = json.loads(response_text)

# Can you understand the data?
data
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2019 The New York Times Company. All Rights Reserved.',
#  'response': {'docs': [{'web_url': 'https://www.nytimes.com/2019/02/10/arts/music/grammy-awards.html',
#     'snippet': 'At a ceremony dominated by female performers and presenters, Musgraves won album of the year for “Golden Hour,” as well as three other awards.',
#     'lead_paragraph': 'At a ceremony dominated by female performers and presenters, Musgraves won album of the year for “Golden Hour,” as well as three other awards.',
#     'print_page': '1',
#     'blog': {},
#     'source': 'The New York Times',
#     'multimedia': [{'rank': 0,
#       'subtype': 'xlarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-articleLarge.jpg',
#       'height': 404,
#       'width': 600,
#       'legacy': {'xlarge': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-articleLarge.jpg',
#        'xlargewidth': 600,
#        'xlargeheight': 404},
#       'subType': 'xlarge',
#       'crop_name': 'articleLarge'},
#      {'rank': 0,
#       'subtype': 'wide',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-thumbWide.jpg',
#       'height': 126,
#       'width': 190,
#       'legacy': {'wide': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-thumbWide.jpg',
#        'widewidth': 190,
#        'wideheight': 126},
#       'subType': 'wide',
#       'crop_name': 'thumbWide'},
#      {'rank': 0,
#       'subtype': 'thumbnail',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-thumbStandard.jpg',
#       'height': 75,
#       'width': 75,
#       'legacy': {'thumbnail': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-thumbStandard.jpg',
#        'thumbnailwidth': 75,
#        'thumbnailheight': 75},
#       'subType': 'thumbnail',
#       'crop_name': 'thumbStandard'},
#      {'rank': 0,
#       'subtype': 'articleInline',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-articleInline.jpg',
#       'height': 128,
#       'width': 190,
#       'legacy': {},
#       'subType': 'articleInline',
#       'crop_name': 'articleInline'},
#      {'rank': 0,
#       'subtype': 'blog225',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-blog225.jpg',
#       'height': 152,
#       'width': 225,
#       'legacy': {},
#       'subType': 'blog225',
#       'crop_name': 'blog225'},
#      {'rank': 0,
#       'subtype': 'blog427',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-blog427.jpg',
#       'height': 288,
#       'width': 427,
#       'legacy': {},
#       'subType': 'blog427',
#       'crop_name': 'blog427'},
#      {'rank': 0,
#       'subtype': 'blog480',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-blog480.jpg',
#       'height': 323,
#       'width': 480,
#       'legacy': {},
#       'subType': 'blog480',
#       'crop_name': 'blog480'},
#      {'rank': 0,
#       'subtype': 'blog533',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-blog533.jpg',
#       'height': 359,
#       'width': 533,
#       'legacy': {},
#       'subType': 'blog533',
#       'crop_name': 'blog533'},
#      {'rank': 0,
#       'subtype': 'blogSmallInline',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-blogSmallInline.jpg',
#       'height': 102,
#       'width': 151,
#       'legacy': {},
#       'subType': 'blogSmallInline',
#       'crop_name': 'blogSmallInline'},
#      {'rank': 0,
#       'subtype': 'blogSmallThumb',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-blogSmallThumb.jpg',
#       'height': 50,
#       'width': 50,
#       'legacy': {},
#       'subType': 'blogSmallThumb',
#       'crop_name': 'blogSmallThumb'},
#      {'rank': 0,
#       'subtype': 'facebookJumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-facebookJumbo.jpg',
#       'height': 549,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'facebookJumbo',
#       'crop_name': 'facebookJumbo'},
#      {'rank': 0,
#       'subtype': 'filmstrip',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-filmstrip.jpg',
#       'height': 190,
#       'width': 190,
#       'legacy': {},
#       'subType': 'filmstrip',
#       'crop_name': 'filmstrip'},
#      {'rank': 0,
#       'subtype': 'hpLarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-hpLarge.jpg',
#       'height': 288,
#       'width': 511,
#       'legacy': {},
#       'subType': 'hpLarge',
#       'crop_name': 'hpLarge'},
#      {'rank': 0,
#       'subtype': 'hpSmall',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-hpSmall.jpg',
#       'height': 110,
#       'width': 163,
#       'legacy': {},
#       'subType': 'hpSmall',
#       'crop_name': 'hpSmall'},
#      {'rank': 0,
#       'subtype': 'jumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-jumbo.jpg',
#       'height': 690,
#       'width': 1024,
#       'legacy': {},
#       'subType': 'jumbo',
#       'crop_name': 'jumbo'},
#      {'rank': 0,
#       'subtype': 'largeHorizontal375',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-largeHorizontal375.jpg',
#       'height': 250,
#       'width': 375,
#       'legacy': {},
#       'subType': 'largeHorizontal375',
#       'crop_name': 'largeHorizontal375'},
#      {'rank': 0,
#       'subtype': 'largeHorizontalJumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-largeHorizontalJumbo.jpg',
#       'height': 683,
#       'width': 1024,
#       'legacy': {},
#       'subType': 'largeHorizontalJumbo',
#       'crop_name': 'largeHorizontalJumbo'},
#      {'rank': 0,
#       'subtype': 'largeWidescreen573',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-largeWidescreen573.jpg',
#       'height': 322,
#       'width': 573,
#       'legacy': {},
#       'subType': 'largeWidescreen573',
#       'crop_name': 'largeWidescreen573'},
#      {'rank': 0,
#       'subtype': 'largeWidescreen1050',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-largeWidescreen1050.jpg',
#       'height': 591,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'largeWidescreen1050',
#       'crop_name': 'largeWidescreen1050'},
#      {'rank': 0,
#       'subtype': 'master1050',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-master1050.jpg',
#       'height': 707,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'master1050',
#       'crop_name': 'master1050'},
#      {'rank': 0,
#       'subtype': 'master180',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-master180.jpg',
#       'height': 121,
#       'width': 180,
#       'legacy': {},
#       'subType': 'master180',
#       'crop_name': 'master180'},
#      {'rank': 0,
#       'subtype': 'master315',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-master315.jpg',
#       'height': 212,
#       'width': 315,
#       'legacy': {},
#       'subType': 'master315',
#       'crop_name': 'master315'},
#      {'rank': 0,
#       'subtype': 'master495',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-master495.jpg',
#       'height': 333,
#       'width': 495,
#       'legacy': {},
#       'subType': 'master495',
#       'crop_name': 'master495'},
#      {'rank': 0,
#       'subtype': 'master768',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-master768.jpg',
#       'height': 517,
#       'width': 768,
#       'legacy': {},
#       'subType': 'master768',
#       'crop_name': 'master768'},
#      {'rank': 0,
#       'subtype': 'master675',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-master675.jpg',
#       'height': 455,
#       'width': 675,
#       'legacy': {},
#       'subType': 'master675',
#       'crop_name': 'master675'},
#      {'rank': 0,
#       'subtype': 'mediumFlexible177',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-mediumFlexible177.jpg',
#       'height': 119,
#       'width': 177,
#       'legacy': {},
#       'subType': 'mediumFlexible177',
#       'crop_name': 'mediumFlexible177'},
#      {'rank': 0,
#       'subtype': 'mediumSquare149',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-mediumSquare149.jpg',
#       'height': 149,
#       'width': 149,
#       'legacy': {},
#       'subType': 'mediumSquare149',
#       'crop_name': 'mediumSquare149'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo210',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-mediumThreeByTwo210.jpg',
#       'height': 140,
#       'width': 210,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo210',
#       'crop_name': 'mediumThreeByTwo210'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo225',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-mediumThreeByTwo225.jpg',
#       'height': 150,
#       'width': 225,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo225',
#       'crop_name': 'mediumThreeByTwo225'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo440',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-mediumThreeByTwo440.jpg',
#       'height': 293,
#       'width': 440,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo440',
#       'crop_name': 'mediumThreeByTwo440'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo378',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-mediumThreeByTwo378.jpg',
#       'height': 252,
#       'width': 378,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo378',
#       'crop_name': 'mediumThreeByTwo378'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo252',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-mediumThreeByTwo252.jpg',
#       'height': 168,
#       'width': 252,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo252',
#       'crop_name': 'mediumThreeByTwo252'},
#      {'rank': 0,
#       'subtype': 'miniMoth',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-miniMoth.jpg',
#       'height': 70,
#       'width': 151,
#       'legacy': {},
#       'subType': 'miniMoth',
#       'crop_name': 'miniMoth'},
#      {'rank': 0,
#       'subtype': 'moth',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-moth.jpg',
#       'height': 151,
#       'width': 151,
#       'legacy': {},
#       'subType': 'moth',
#       'crop_name': 'moth'},
#      {'rank': 0,
#       'subtype': 'popup',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-popup.jpg',
#       'height': 438,
#       'width': 650,
#       'legacy': {},
#       'subType': 'popup',
#       'crop_name': 'popup'},
#      {'rank': 0,
#       'subtype': 'sfSpan',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-sfSpan.jpg',
#       'height': 263,
#       'width': 395,
#       'legacy': {},
#       'subType': 'sfSpan',
#       'crop_name': 'sfSpan'},
#      {'rank': 0,
#       'subtype': 'slide',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-slide.jpg',
#       'height': 404,
#       'width': 600,
#       'legacy': {},
#       'subType': 'slide',
#       'crop_name': 'slide'},
#      {'rank': 0,
#       'subtype': 'smallSquare168',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-smallSquare168.jpg',
#       'height': 168,
#       'width': 168,
#       'legacy': {},
#       'subType': 'smallSquare168',
#       'crop_name': 'smallSquare168'},
#      {'rank': 0,
#       'subtype': 'smallSquare252',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-smallSquare252.jpg',
#       'height': 252,
#       'width': 252,
#       'legacy': {},
#       'subType': 'smallSquare252',
#       'crop_name': 'smallSquare252'},
#      {'rank': 0,
#       'subtype': 'square320',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-square320.jpg',
#       'height': 320,
#       'width': 320,
#       'legacy': {},
#       'subType': 'square320',
#       'crop_name': 'square320'},
#      {'rank': 0,
#       'subtype': 'square640',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-square640.jpg',
#       'height': 640,
#       'width': 640,
#       'legacy': {},
#       'subType': 'square640',
#       'crop_name': 'square640'},
#      {'rank': 0,
#       'subtype': 'superJumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-superJumbo.jpg',
#       'height': 1379,
#       'width': 2048,
#       'legacy': {},
#       'subType': 'superJumbo',
#       'crop_name': 'superJumbo'},
#      {'rank': 0,
#       'subtype': 'thumbLarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-thumbLarge.jpg',
#       'height': 150,
#       'width': 150,
#       'legacy': {},
#       'subType': 'thumbLarge',
#       'crop_name': 'thumbLarge'},
#      {'rank': 0,
#       'subtype': 'tmagArticle',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-tmagArticle.jpg',
#       'height': 399,
#       'width': 592,
#       'legacy': {},
#       'subType': 'tmagArticle',
#       'crop_name': 'tmagArticle'},
#      {'rank': 0,
#       'subtype': 'tmagSF',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-tmagSF.jpg',
#       'height': 244,
#       'width': 362,
#       'legacy': {},
#       'subType': 'tmagSF',
#       'crop_name': 'tmagSF'},
#      {'rank': 0,
#       'subtype': 'verticalTwoByThree735',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-verticalTwoByThree735.jpg',
#       'height': 1102,
#       'width': 735,
#       'legacy': {},
#       'subType': 'verticalTwoByThree735',
#       'crop_name': 'verticalTwoByThree735'},
#      {'rank': 0,
#       'subtype': 'videoFifteenBySeven1305',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-videoFifteenBySeven1305.jpg',
#       'height': 609,
#       'width': 1305,
#       'legacy': {},
#       'subType': 'videoFifteenBySeven1305',
#       'crop_name': 'videoFifteenBySeven1305'},
#      {'rank': 0,
#       'subtype': 'videoFifteenBySeven2610',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-videoFifteenBySeven2610.jpg',
#       'height': 1218,
#       'width': 2610,
#       'legacy': {},
#       'subType': 'videoFifteenBySeven2610',
#       'crop_name': 'videoFifteenBySeven2610'},
#      {'rank': 0,
#       'subtype': 'videoHpMedium',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/11grammys-live-drake-videoHpMedium.jpg',
#       'height': 211,
#       'width': 375,
#       'legacy': {},
#       'subType': 'videoHpMedium',
#       'crop_name': 'videoHpMedium'},
#      {'rank': 0,
#       'subtype': 'videoLarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-videoLarge.jpg',
#       'height': 507,
#       'width': 768,
#       'legacy': {},
#       'subType': 'videoLarge',
#       'crop_name': 'videoLarge'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine1050',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/11grammys-live-drake-videoSixteenByNine1050.jpg',
#       'height': 591,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'videoSixteenByNine1050',
#       'crop_name': 'videoSixteenByNine1050'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine150',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/11grammys-live-drake-videoSixteenByNine150.jpg',
#       'height': 84,
#       'width': 150,
#       'legacy': {},
#       'subType': 'videoSixteenByNine150',
#       'crop_name': 'videoSixteenByNine150'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine225',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/11grammys-live-drake-videoSixteenByNine225.jpg',
#       'height': 126,
#       'width': 225,
#       'legacy': {},
#       'subType': 'videoSixteenByNine225',
#       'crop_name': 'videoSixteenByNine225'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine310',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/11grammys-live-drake-videoSixteenByNine310.jpg',
#       'height': 174,
#       'width': 310,
#       'legacy': {},
#       'subType': 'videoSixteenByNine310',
#       'crop_name': 'videoSixteenByNine310'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine390',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/11grammys-live-drake-videoSixteenByNine390.jpg',
#       'height': 219,
#       'width': 390,
#       'legacy': {},
#       'subType': 'videoSixteenByNine390',
#       'crop_name': 'videoSixteenByNine390'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine480',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/11grammys-live-drake-videoSixteenByNine480.jpg',
#       'height': 270,
#       'width': 480,
#       'legacy': {},
#       'subType': 'videoSixteenByNine480',
#       'crop_name': 'videoSixteenByNine480'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine495',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/11grammys-live-drake-videoSixteenByNine495.jpg',
#       'height': 278,
#       'width': 495,
#       'legacy': {},
#       'subType': 'videoSixteenByNine495',
#       'crop_name': 'videoSixteenByNine495'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine540',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/11grammys-live-drake-videoSixteenByNine540.jpg',
#       'height': 304,
#       'width': 540,
#       'legacy': {},
#       'subType': 'videoSixteenByNine540',
#       'crop_name': 'videoSixteenByNine540'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine600',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/11grammys-live-drake-videoSixteenByNine600.jpg',
#       'height': 338,
#       'width': 600,
#       'legacy': {},
#       'subType': 'videoSixteenByNine600',
#       'crop_name': 'videoSixteenByNine600'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine768',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/11grammys-live-drake-videoSixteenByNine768.jpg',
#       'height': 432,
#       'width': 768,
#       'legacy': {},
#       'subType': 'videoSixteenByNine768',
#       'crop_name': 'videoSixteenByNine768'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine96',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/11grammys-live-drake-videoSixteenByNine96.jpg',
#       'height': 54,
#       'width': 96,
#       'legacy': {},
#       'subType': 'videoSixteenByNine96',
#       'crop_name': 'videoSixteenByNine96'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNineJumbo1600',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/11grammys-live-drake-videoSixteenByNineJumbo1600.jpg',
#       'height': 900,
#       'width': 1600,
#       'legacy': {},
#       'subType': 'videoSixteenByNineJumbo1600',
#       'crop_name': 'videoSixteenByNineJumbo1600'},
#      {'rank': 0,
#       'subtype': 'videoSmall',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/11grammys-live-drake-videoSmall.jpg',
#       'height': 281,
#       'width': 500,
#       'legacy': {},
#       'subType': 'videoSmall',
#       'crop_name': 'videoSmall'},
#      {'rank': 0,
#       'subtype': 'videoThumb',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-videoThumb.jpg',
#       'height': 50,
#       'width': 75,
#       'legacy': {},
#       'subType': 'videoThumb',
#       'crop_name': 'videoThumb'},
#      {'rank': 0,
#       'subtype': 'watch268',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-watch268.jpg',
#       'height': 303,
#       'width': 272,
#       'legacy': {},
#       'subType': 'watch268',
#       'crop_name': 'watch268'},
#      {'rank': 0,
#       'subtype': 'watch308',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-watch308.jpg',
#       'height': 348,
#       'width': 312,
#       'legacy': {},
#       'subType': 'watch308',
#       'crop_name': 'watch308'},
#      {'rank': 0,
#       'subtype': 'windowsTile336H',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/11/arts/11grammys-live-drake/merlin_150509697_1c8fbc37-51be-43a3-a4fd-8f02e8308856-windowsTile336H.jpg',
#       'height': 336,
#       'width': 694,
#       'legacy': {},
#       'subType': 'windowsTile336H',
#       'crop_name': 'windowsTile336H'}],
#     'headline': {'main': 'Grammys 2019: Cardi B, Lady Gaga and Kacey Musgraves Make It a Year for Women',
#      'kicker': '',
#      'content_kicker': '',
#      'print_headline': 'Music and Scrutiny at the Grammys',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Grammy Awards',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Music', 'rank': 2, 'major': 'N'},
#      {'name': 'subject', 'value': 'Women and Girls', 'rank': 3, 'major': 'N'},
#      {'name': 'persons', 'value': 'Keys, Alicia', 'rank': 4, 'major': 'N'},
#      {'name': 'persons', 'value': 'Lipa, Dua', 'rank': 5, 'major': 'N'},
#      {'name': 'persons', 'value': 'Musgraves, Kacey', 'rank': 6, 'major': 'N'},
#      {'name': 'persons', 'value': 'Cardi B (1992- )', 'rank': 7, 'major': 'N'},
#      {'name': 'persons', 'value': 'Lady Gaga', 'rank': 8, 'major': 'N'},
#      {'name': 'persons', 'value': 'Obama, Michelle', 'rank': 9, 'major': 'N'},
#      {'name': 'persons', 'value': 'Parton, Dolly', 'rank': 10, 'major': 'N'},
#      {'name': 'persons', 'value': 'Ross, Diana', 'rank': 11, 'major': 'N'},
#      {'name': 'creative_works',
#       'value': 'Golden Hour (Album)',
#       'rank': 12,
#       'major': 'N'}],
#     'pub_date': '2019-02-10T22:00:04+0000',
#     'document_type': 'article',
#     'news_desk': 'Culture',
#     'section_name': 'Arts',
#     'subsectoinName': 'Music',
#     'byline': {'original': 'By BEN SISARIO',
#      'person': [{'firstname': 'Ben',
#        'middlename': None,
#        'lastname': 'SISARIO',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': '5c609f3e3a125f5075c08fb5',
#     'word_count': 1866,
#     'score': 0.0,
#     'uri': 'nyt://article/ca133f47-73b9-554d-871c-35a741154b94'},
#    {'web_url': 'https://www.nytimes.com/2019/01/10/arts/music/rat-boy-internationally-unknown.html',
#     'snippet': 'The 22-year-old English musician Jordan Cardy sends up authority and celebrates slackerdom in songs that combine the energy of punk with the storytelling of hip-hop.',
#     'lead_paragraph': 'The 22-year-old English musician Jordan Cardy sends up authority and celebrates slackerdom in songs that combine the energy of punk with the storytelling of hip-hop.',
#     'print_page': '16',
#     'blog': {},
#     'source': 'The New York Times',
#     'multimedia': [{'rank': 0,
#       'subtype': 'xlarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/merlin_148718151_8fa1d02f-224d-4e88-8d9c-71a714512b0c-articleLarge.jpg',
#       'height': 480,
#       'width': 600,
#       'legacy': {'xlarge': 'images/2019/01/13/arts/13ratboy2/merlin_148718151_8fa1d02f-224d-4e88-8d9c-71a714512b0c-articleLarge.jpg',
#        'xlargewidth': 600,
#        'xlargeheight': 480},
#       'subType': 'xlarge',
#       'crop_name': 'articleLarge'},
#      {'rank': 0,
#       'subtype': 'wide',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-thumbWide-v2.jpg',
#       'height': 126,
#       'width': 190,
#       'legacy': {'wide': 'images/2019/01/13/arts/13ratboy2/13ratboy2-thumbWide-v2.jpg',
#        'widewidth': 190,
#        'wideheight': 126},
#       'subType': 'wide',
#       'crop_name': 'thumbWide'},
#      {'rank': 0,
#       'subtype': 'thumbnail',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-thumbStandard.jpg',
#       'height': 75,
#       'width': 75,
#       'legacy': {'thumbnail': 'images/2019/01/13/arts/13ratboy2/13ratboy2-thumbStandard.jpg',
#        'thumbnailwidth': 75,
#        'thumbnailheight': 75},
#       'subType': 'thumbnail',
#       'crop_name': 'thumbStandard'},
#      {'rank': 0,
#       'subtype': 'articleInline',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/merlin_148718151_8fa1d02f-224d-4e88-8d9c-71a714512b0c-articleInline.jpg',
#       'height': 152,
#       'width': 190,
#       'legacy': {},
#       'subType': 'articleInline',
#       'crop_name': 'articleInline'},
#      {'rank': 0,
#       'subtype': 'blog225',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/merlin_148718151_8fa1d02f-224d-4e88-8d9c-71a714512b0c-blog225.jpg',
#       'height': 180,
#       'width': 225,
#       'legacy': {},
#       'subType': 'blog225',
#       'crop_name': 'blog225'},
#      {'rank': 0,
#       'subtype': 'blog427',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/merlin_148718151_8fa1d02f-224d-4e88-8d9c-71a714512b0c-blog427.jpg',
#       'height': 342,
#       'width': 427,
#       'legacy': {},
#       'subType': 'blog427',
#       'crop_name': 'blog427'},
#      {'rank': 0,
#       'subtype': 'blog480',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/merlin_148718151_8fa1d02f-224d-4e88-8d9c-71a714512b0c-blog480.jpg',
#       'height': 384,
#       'width': 480,
#       'legacy': {},
#       'subType': 'blog480',
#       'crop_name': 'blog480'},
#      {'rank': 0,
#       'subtype': 'blog533',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/merlin_148718151_8fa1d02f-224d-4e88-8d9c-71a714512b0c-blog533.jpg',
#       'height': 426,
#       'width': 533,
#       'legacy': {},
#       'subType': 'blog533',
#       'crop_name': 'blog533'},
#      {'rank': 0,
#       'subtype': 'blogSmallInline',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/merlin_148718151_8fa1d02f-224d-4e88-8d9c-71a714512b0c-blogSmallInline.jpg',
#       'height': 121,
#       'width': 151,
#       'legacy': {},
#       'subType': 'blogSmallInline',
#       'crop_name': 'blogSmallInline'},
#      {'rank': 0,
#       'subtype': 'blogSmallThumb',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-blogSmallThumb.jpg',
#       'height': 50,
#       'width': 50,
#       'legacy': {},
#       'subType': 'blogSmallThumb',
#       'crop_name': 'blogSmallThumb'},
#      {'rank': 0,
#       'subtype': 'facebookJumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-facebookJumbo.jpg',
#       'height': 550,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'facebookJumbo',
#       'crop_name': 'facebookJumbo'},
#      {'rank': 0,
#       'subtype': 'filmstrip',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-filmstrip.jpg',
#       'height': 190,
#       'width': 190,
#       'legacy': {},
#       'subType': 'filmstrip',
#       'crop_name': 'filmstrip'},
#      {'rank': 0,
#       'subtype': 'hpLarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-hpLarge.jpg',
#       'height': 287,
#       'width': 511,
#       'legacy': {},
#       'subType': 'hpLarge',
#       'crop_name': 'hpLarge'},
#      {'rank': 0,
#       'subtype': 'hpSmall',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/merlin_148718151_8fa1d02f-224d-4e88-8d9c-71a714512b0c-hpSmall.jpg',
#       'height': 130,
#       'width': 163,
#       'legacy': {},
#       'subType': 'hpSmall',
#       'crop_name': 'hpSmall'},
#      {'rank': 0,
#       'subtype': 'jumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/merlin_148718151_8fa1d02f-224d-4e88-8d9c-71a714512b0c-jumbo.jpg',
#       'height': 819,
#       'width': 1024,
#       'legacy': {},
#       'subType': 'jumbo',
#       'crop_name': 'jumbo'},
#      {'rank': 0,
#       'subtype': 'largeHorizontal375',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-largeHorizontal375-v2.jpg',
#       'height': 250,
#       'width': 375,
#       'legacy': {},
#       'subType': 'largeHorizontal375',
#       'crop_name': 'largeHorizontal375'},
#      {'rank': 0,
#       'subtype': 'largeHorizontalJumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-largeHorizontalJumbo-v2.jpg',
#       'height': 683,
#       'width': 1024,
#       'legacy': {},
#       'subType': 'largeHorizontalJumbo',
#       'crop_name': 'largeHorizontalJumbo'},
#      {'rank': 0,
#       'subtype': 'largeWidescreen573',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-largeWidescreen573.jpg',
#       'height': 322,
#       'width': 573,
#       'legacy': {},
#       'subType': 'largeWidescreen573',
#       'crop_name': 'largeWidescreen573'},
#      {'rank': 0,
#       'subtype': 'largeWidescreen1050',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-largeWidescreen1050.jpg',
#       'height': 590,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'largeWidescreen1050',
#       'crop_name': 'largeWidescreen1050'},
#      {'rank': 0,
#       'subtype': 'master1050',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/merlin_148718151_8fa1d02f-224d-4e88-8d9c-71a714512b0c-master1050.jpg',
#       'height': 840,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'master1050',
#       'crop_name': 'master1050'},
#      {'rank': 0,
#       'subtype': 'master180',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/merlin_148718151_8fa1d02f-224d-4e88-8d9c-71a714512b0c-master180.jpg',
#       'height': 144,
#       'width': 180,
#       'legacy': {},
#       'subType': 'master180',
#       'crop_name': 'master180'},
#      {'rank': 0,
#       'subtype': 'master315',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/merlin_148718151_8fa1d02f-224d-4e88-8d9c-71a714512b0c-master315.jpg',
#       'height': 252,
#       'width': 315,
#       'legacy': {},
#       'subType': 'master315',
#       'crop_name': 'master315'},
#      {'rank': 0,
#       'subtype': 'master495',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/merlin_148718151_8fa1d02f-224d-4e88-8d9c-71a714512b0c-master495.jpg',
#       'height': 396,
#       'width': 495,
#       'legacy': {},
#       'subType': 'master495',
#       'crop_name': 'master495'},
#      {'rank': 0,
#       'subtype': 'master768',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/merlin_148718151_8fa1d02f-224d-4e88-8d9c-71a714512b0c-master768.jpg',
#       'height': 614,
#       'width': 768,
#       'legacy': {},
#       'subType': 'master768',
#       'crop_name': 'master768'},
#      {'rank': 0,
#       'subtype': 'master675',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/merlin_148718151_8fa1d02f-224d-4e88-8d9c-71a714512b0c-master675.jpg',
#       'height': 540,
#       'width': 675,
#       'legacy': {},
#       'subType': 'master675',
#       'crop_name': 'master675'},
#      {'rank': 0,
#       'subtype': 'mediumFlexible177',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/merlin_148718151_8fa1d02f-224d-4e88-8d9c-71a714512b0c-mediumFlexible177.jpg',
#       'height': 142,
#       'width': 177,
#       'legacy': {},
#       'subType': 'mediumFlexible177',
#       'crop_name': 'mediumFlexible177'},
#      {'rank': 0,
#       'subtype': 'mediumSquare149',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-mediumSquare149.jpg',
#       'height': 149,
#       'width': 149,
#       'legacy': {},
#       'subType': 'mediumSquare149',
#       'crop_name': 'mediumSquare149'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo210',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-mediumThreeByTwo210-v2.jpg',
#       'height': 140,
#       'width': 210,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo210',
#       'crop_name': 'mediumThreeByTwo210'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo225',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-mediumThreeByTwo225-v2.jpg',
#       'height': 150,
#       'width': 225,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo225',
#       'crop_name': 'mediumThreeByTwo225'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo440',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-mediumThreeByTwo440-v2.jpg',
#       'height': 293,
#       'width': 440,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo440',
#       'crop_name': 'mediumThreeByTwo440'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo378',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-mediumThreeByTwo378-v2.jpg',
#       'height': 252,
#       'width': 378,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo378',
#       'crop_name': 'mediumThreeByTwo378'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo252',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-mediumThreeByTwo252-v2.jpg',
#       'height': 168,
#       'width': 252,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo252',
#       'crop_name': 'mediumThreeByTwo252'},
#      {'rank': 0,
#       'subtype': 'miniMoth',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-miniMoth.jpg',
#       'height': 70,
#       'width': 151,
#       'legacy': {},
#       'subType': 'miniMoth',
#       'crop_name': 'miniMoth'},
#      {'rank': 0,
#       'subtype': 'moth',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-moth.jpg',
#       'height': 151,
#       'width': 151,
#       'legacy': {},
#       'subType': 'moth',
#       'crop_name': 'moth'},
#      {'rank': 0,
#       'subtype': 'popup',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/merlin_148718151_8fa1d02f-224d-4e88-8d9c-71a714512b0c-popup.jpg',
#       'height': 500,
#       'width': 625,
#       'legacy': {},
#       'subType': 'popup',
#       'crop_name': 'popup'},
#      {'rank': 0,
#       'subtype': 'sfSpan',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-sfSpan-v2.jpg',
#       'height': 263,
#       'width': 395,
#       'legacy': {},
#       'subType': 'sfSpan',
#       'crop_name': 'sfSpan'},
#      {'rank': 0,
#       'subtype': 'slide',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/merlin_148718151_8fa1d02f-224d-4e88-8d9c-71a714512b0c-slide.jpg',
#       'height': 480,
#       'width': 600,
#       'legacy': {},
#       'subType': 'slide',
#       'crop_name': 'slide'},
#      {'rank': 0,
#       'subtype': 'smallSquare168',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-smallSquare168.jpg',
#       'height': 168,
#       'width': 168,
#       'legacy': {},
#       'subType': 'smallSquare168',
#       'crop_name': 'smallSquare168'},
#      {'rank': 0,
#       'subtype': 'smallSquare252',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-smallSquare252.jpg',
#       'height': 252,
#       'width': 252,
#       'legacy': {},
#       'subType': 'smallSquare252',
#       'crop_name': 'smallSquare252'},
#      {'rank': 0,
#       'subtype': 'square320',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-square320.jpg',
#       'height': 320,
#       'width': 320,
#       'legacy': {},
#       'subType': 'square320',
#       'crop_name': 'square320'},
#      {'rank': 0,
#       'subtype': 'square640',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-square640.jpg',
#       'height': 640,
#       'width': 640,
#       'legacy': {},
#       'subType': 'square640',
#       'crop_name': 'square640'},
#      {'rank': 0,
#       'subtype': 'superJumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/merlin_148718151_8fa1d02f-224d-4e88-8d9c-71a714512b0c-superJumbo.jpg',
#       'height': 1638,
#       'width': 2048,
#       'legacy': {},
#       'subType': 'superJumbo',
#       'crop_name': 'superJumbo'},
#      {'rank': 0,
#       'subtype': 'thumbLarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-thumbLarge.jpg',
#       'height': 150,
#       'width': 150,
#       'legacy': {},
#       'subType': 'thumbLarge',
#       'crop_name': 'thumbLarge'},
#      {'rank': 0,
#       'subtype': 'tmagArticle',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/merlin_148718151_8fa1d02f-224d-4e88-8d9c-71a714512b0c-tmagArticle.jpg',
#       'height': 474,
#       'width': 592,
#       'legacy': {},
#       'subType': 'tmagArticle',
#       'crop_name': 'tmagArticle'},
#      {'rank': 0,
#       'subtype': 'tmagSF',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/merlin_148718151_8fa1d02f-224d-4e88-8d9c-71a714512b0c-tmagSF.jpg',
#       'height': 290,
#       'width': 362,
#       'legacy': {},
#       'subType': 'tmagSF',
#       'crop_name': 'tmagSF'},
#      {'rank': 0,
#       'subtype': 'verticalTwoByThree735',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-verticalTwoByThree735.jpg',
#       'height': 1103,
#       'width': 735,
#       'legacy': {},
#       'subType': 'verticalTwoByThree735',
#       'crop_name': 'verticalTwoByThree735'},
#      {'rank': 0,
#       'subtype': 'videoFifteenBySeven1305',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-videoFifteenBySeven1305.jpg',
#       'height': 609,
#       'width': 1305,
#       'legacy': {},
#       'subType': 'videoFifteenBySeven1305',
#       'crop_name': 'videoFifteenBySeven1305'},
#      {'rank': 0,
#       'subtype': 'videoFifteenBySeven2610',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-videoFifteenBySeven2610.jpg',
#       'height': 1218,
#       'width': 2610,
#       'legacy': {},
#       'subType': 'videoFifteenBySeven2610',
#       'crop_name': 'videoFifteenBySeven2610'},
#      {'rank': 0,
#       'subtype': 'videoHpMedium',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-videoHpMedium.jpg',
#       'height': 211,
#       'width': 375,
#       'legacy': {},
#       'subType': 'videoHpMedium',
#       'crop_name': 'videoHpMedium'},
#      {'rank': 0,
#       'subtype': 'videoLarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-videoLarge-v2.jpg',
#       'height': 507,
#       'width': 768,
#       'legacy': {},
#       'subType': 'videoLarge',
#       'crop_name': 'videoLarge'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine1050',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-videoSixteenByNine1050.jpg',
#       'height': 591,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'videoSixteenByNine1050',
#       'crop_name': 'videoSixteenByNine1050'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine150',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-videoSixteenByNine150.jpg',
#       'height': 84,
#       'width': 150,
#       'legacy': {},
#       'subType': 'videoSixteenByNine150',
#       'crop_name': 'videoSixteenByNine150'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine225',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-videoSixteenByNine225.jpg',
#       'height': 126,
#       'width': 225,
#       'legacy': {},
#       'subType': 'videoSixteenByNine225',
#       'crop_name': 'videoSixteenByNine225'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine3000',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-videoSixteenByNine3000.jpg',
#       'height': 1687,
#       'width': 3000,
#       'legacy': {},
#       'subType': 'videoSixteenByNine3000',
#       'crop_name': 'videoSixteenByNine3000'},
#      {'rank': 0,
# ...
#       'height': 140,
#       'width': 210,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo210',
#       'crop_name': 'mediumThreeByTwo210'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo225',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/04/obituaries/04SYLVAN-OBIT/02SYLVAN3-mediumThreeByTwo225.jpg',
#       'height': 150,
#       'width': 225,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo225',
#       'crop_name': 'mediumThreeByTwo225'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo440',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/04/obituaries/04SYLVAN-OBIT/02SYLVAN3-mediumThreeByTwo440.jpg',
#       'height': 293,
#       'width': 440,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo440',
#       'crop_name': 'mediumThreeByTwo440'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo378',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/04/obituaries/04SYLVAN-OBIT/02SYLVAN3-mediumThreeByTwo378.jpg',
#       'height': 252,
#       'width': 378,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo378',
#       'crop_name': 'mediumThreeByTwo378'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo252',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/04/obituaries/04SYLVAN-OBIT/02SYLVAN3-mediumThreeByTwo252.jpg',
#       'height': 168,
#       'width': 252,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo252',
#       'crop_name': 'mediumThreeByTwo252'},
#      {'rank': 0,
#       'subtype': 'miniMoth',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/04/obituaries/04SYLVAN-OBIT/02SYLVAN3-miniMoth.jpg',
#       'height': 70,
#       'width': 151,
#       'legacy': {},
#       'subType': 'miniMoth',
#       'crop_name': 'miniMoth'},
#      {'rank': 0,
#       'subtype': 'moth',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/04/obituaries/04SYLVAN-OBIT/02SYLVAN3-moth.jpg',
#       'height': 151,
#       'width': 151,
#       'legacy': {},
#       'subType': 'moth',
#       'crop_name': 'moth'},
#      {'rank': 0,
#       'subtype': 'popup',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/04/obituaries/04SYLVAN-OBIT/merlin_150070437_cd7f140b-19b8-4ed1-8a19-017941e9c8c7-popup.jpg',
#       'height': 500,
#       'width': 284,
#       'legacy': {},
#       'subType': 'popup',
#       'crop_name': 'popup'},
#      {'rank': 0,
#       'subtype': 'sfSpan',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/04/obituaries/04SYLVAN-OBIT/02SYLVAN3-sfSpan.jpg',
#       'height': 263,
#       'width': 395,
#       'legacy': {},
#       'subType': 'sfSpan',
#       'crop_name': 'sfSpan'},
#      {'rank': 0,
#       'subtype': 'slide',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/04/obituaries/04SYLVAN-OBIT/merlin_150070437_cd7f140b-19b8-4ed1-8a19-017941e9c8c7-slide.jpg',
#       'height': 500,
#       'width': 284,
#       'legacy': {},
#       'subType': 'slide',
#       'crop_name': 'slide'},
#      {'rank': 0,
#       'subtype': 'smallSquare168',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/04/obituaries/04SYLVAN-OBIT/02SYLVAN3-smallSquare168.jpg',
#       'height': 168,
#       'width': 168,
#       'legacy': {},
#       'subType': 'smallSquare168',
#       'crop_name': 'smallSquare168'},
#      {'rank': 0,
#       'subtype': 'smallSquare252',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/04/obituaries/04SYLVAN-OBIT/02SYLVAN3-smallSquare252.jpg',
#       'height': 252,
#       'width': 252,
#       'legacy': {},
#       'subType': 'smallSquare252',
#       'crop_name': 'smallSquare252'},
#      {'rank': 0,
#       'subtype': 'square320',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/04/obituaries/04SYLVAN-OBIT/02SYLVAN3-square320.jpg',
#       'height': 320,
#       'width': 320,
#       'legacy': {},
#       'subType': 'square320',
#       'crop_name': 'square320'},
#      {'rank': 0,
#       'subtype': 'square640',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/04/obituaries/04SYLVAN-OBIT/02SYLVAN3-square640.jpg',
#       'height': 640,
#       'width': 640,
#       'legacy': {},
#       'subType': 'square640',
#       'crop_name': 'square640'},
#      {'rank': 0,
#       'subtype': 'superJumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/04/obituaries/04SYLVAN-OBIT/merlin_150070437_cd7f140b-19b8-4ed1-8a19-017941e9c8c7-superJumbo.jpg',
#       'height': 2048,
#       'width': 1162,
#       'legacy': {},
#       'subType': 'superJumbo',
#       'crop_name': 'superJumbo'},
#      {'rank': 0,
#       'subtype': 'thumbLarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/04/obituaries/04SYLVAN-OBIT/02SYLVAN3-thumbLarge.jpg',
#       'height': 150,
#       'width': 150,
#       'legacy': {},
#       'subType': 'thumbLarge',
#       'crop_name': 'thumbLarge'},
#      {'rank': 0,
#       'subtype': 'tmagArticle',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/04/obituaries/04SYLVAN-OBIT/merlin_150070437_cd7f140b-19b8-4ed1-8a19-017941e9c8c7-tmagArticle.jpg',
#       'height': 1044,
#       'width': 592,
#       'legacy': {},
#       'subType': 'tmagArticle',
#       'crop_name': 'tmagArticle'},
#      {'rank': 0,
#       'subtype': 'tmagSF',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/04/obituaries/04SYLVAN-OBIT/merlin_150070437_cd7f140b-19b8-4ed1-8a19-017941e9c8c7-tmagSF.jpg',
#       'height': 638,
#       'width': 362,
#       'legacy': {},
#       'subType': 'tmagSF',
#       'crop_name': 'tmagSF'},
#      {'rank': 0,
#       'subtype': 'verticalTwoByThree735',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/04/obituaries/04SYLVAN-OBIT/02SYLVAN3-verticalTwoByThree735.jpg',
#       'height': 1103,
#       'width': 735,
#       'legacy': {},
#       'subType': 'verticalTwoByThree735',
#       'crop_name': 'verticalTwoByThree735'},
#      {'rank': 0,
#       'subtype': 'videoFifteenBySeven1305',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/04/obituaries/04SYLVAN-OBIT/02SYLVAN3-videoFifteenBySeven1305.jpg',
#       'height': 609,
#       'width': 1305,
#       'legacy': {},
#       'subType': 'videoFifteenBySeven1305',
#       'crop_name': 'videoFifteenBySeven1305'},
#      {'rank': 0,
#       'subtype': 'videoFifteenBySeven2610',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/04/obituaries/04SYLVAN-OBIT/02SYLVAN3-videoFifteenBySeven2610.jpg',
#       'height': 1218,
#       'width': 2610,
#       'legacy': {},
#       'subType': 'videoFifteenBySeven2610',
#       'crop_name': 'videoFifteenBySeven2610'},
#      {'rank': 0,
#       'subtype': 'videoHpMedium',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/04/obituaries/04SYLVAN-OBIT/02SYLVAN3-videoHpMedium.jpg',
#       'height': 211,
#       'width': 375,
#       'legacy': {},
#       'subType': 'videoHpMedium',
#       'crop_name': 'videoHpMedium'},
#      {'rank': 0,
#       'subtype': 'videoLarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/04/obituaries/04SYLVAN-OBIT/02SYLVAN3-videoLarge.jpg',
#       'height': 507,
#       'width': 768,
#       'legacy': {},
#       'subType': 'videoLarge',
#       'crop_name': 'videoLarge'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine1050',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/04/obituaries/04SYLVAN-OBIT/02SYLVAN3-videoSixteenByNine1050.jpg',
#       'height': 591,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'videoSixteenByNine1050',
#       'crop_name': 'videoSixteenByNine1050'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine150',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/04/obituaries/04SYLVAN-OBIT/02SYLVAN3-videoSixteenByNine150.jpg',
#       'height': 84,
#       'width': 150,
#       'legacy': {},
#       'subType': 'videoSixteenByNine150',
#       'crop_name': 'videoSixteenByNine150'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine225',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/04/obituaries/04SYLVAN-OBIT/02SYLVAN3-videoSixteenByNine225.jpg',
#       'height': 126,
#       'width': 225,
#       'legacy': {},
#       'subType': 'videoSixteenByNine225',
#       'crop_name': 'videoSixteenByNine225'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine3000',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/04/obituaries/04SYLVAN-OBIT/02SYLVAN3-videoSixteenByNine3000.jpg',
#       'height': 1689,
#       'width': 3000,
#       'legacy': {},
#       'subType': 'videoSixteenByNine3000',
#       'crop_name': 'videoSixteenByNine3000'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine310',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/04/obituaries/04SYLVAN-OBIT/02SYLVAN3-videoSixteenByNine310.jpg',
#       'height': 174,
#       'width': 310,
#       'legacy': {},
#       'subType': 'videoSixteenByNine310',
#       'crop_name': 'videoSixteenByNine310'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine390',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/04/obituaries/04SYLVAN-OBIT/02SYLVAN3-videoSixteenByNine390.jpg',
#       'height': 219,
#       'width': 390,
#       'legacy': {},
#       'subType': 'videoSixteenByNine390',
#       'crop_name': 'videoSixteenByNine390'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine480',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/04/obituaries/04SYLVAN-OBIT/02SYLVAN3-videoSixteenByNine480.jpg',
#       'height': 270,
#       'width': 480,
#       'legacy': {},
#       'subType': 'videoSixteenByNine480',
#       'crop_name': 'videoSixteenByNine480'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine495',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/04/obituaries/04SYLVAN-OBIT/02SYLVAN3-videoSixteenByNine495.jpg',
#       'height': 278,
#       'width': 495,
#       'legacy': {},
#       'subType': 'videoSixteenByNine495',
#       'crop_name': 'videoSixteenByNine495'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine540',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/04/obituaries/04SYLVAN-OBIT/02SYLVAN3-videoSixteenByNine540.jpg',
#       'height': 304,
#       'width': 540,
#       'legacy': {},
#       'subType': 'videoSixteenByNine540',
#       'crop_name': 'videoSixteenByNine540'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine600',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/04/obituaries/04SYLVAN-OBIT/02SYLVAN3-videoSixteenByNine600.jpg',
#       'height': 338,
#       'width': 600,
#       'legacy': {},
#       'subType': 'videoSixteenByNine600',
#       'crop_name': 'videoSixteenByNine600'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine768',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/04/obituaries/04SYLVAN-OBIT/02SYLVAN3-videoSixteenByNine768.jpg',
#       'height': 432,
#       'width': 768,
#       'legacy': {},
#       'subType': 'videoSixteenByNine768',
#       'crop_name': 'videoSixteenByNine768'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine96',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/04/obituaries/04SYLVAN-OBIT/02SYLVAN3-videoSixteenByNine96.jpg',
#       'height': 54,
#       'width': 96,
#       'legacy': {},
#       'subType': 'videoSixteenByNine96',
#       'crop_name': 'videoSixteenByNine96'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNineJumbo1600',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/04/obituaries/04SYLVAN-OBIT/02SYLVAN3-videoSixteenByNineJumbo1600.jpg',
#       'height': 901,
#       'width': 1600,
#       'legacy': {},
#       'subType': 'videoSixteenByNineJumbo1600',
#       'crop_name': 'videoSixteenByNineJumbo1600'},
#      {'rank': 0,
#       'subtype': 'videoSmall',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/04/obituaries/04SYLVAN-OBIT/02SYLVAN3-videoSmall.jpg',
#       'height': 281,
#       'width': 500,
#       'legacy': {},
#       'subType': 'videoSmall',
#       'crop_name': 'videoSmall'},
#      {'rank': 0,
#       'subtype': 'videoThumb',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/04/obituaries/04SYLVAN-OBIT/02SYLVAN3-videoThumb.jpg',
#       'height': 50,
#       'width': 75,
#       'legacy': {},
#       'subType': 'videoThumb',
#       'crop_name': 'videoThumb'},
#      {'rank': 0,
#       'subtype': 'watch268',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/04/obituaries/04SYLVAN-OBIT/02SYLVAN3-watch268.jpg',
#       'height': 303,
#       'width': 272,
#       'legacy': {},
#       'subType': 'watch268',
#       'crop_name': 'watch268'},
#      {'rank': 0,
#       'subtype': 'watch308',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/04/obituaries/04SYLVAN-OBIT/02SYLVAN3-watch308.jpg',
#       'height': 348,
#       'width': 312,
#       'legacy': {},
#       'subType': 'watch308',
#       'crop_name': 'watch308'},
#      {'rank': 0,
#       'subtype': 'windowsTile336H',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/02/04/obituaries/04SYLVAN-OBIT/02SYLVAN3-windowsTile336H.jpg',
#       'height': 336,
#       'width': 694,
#       'legacy': {},
#       'subType': 'windowsTile336H',
#       'crop_name': 'windowsTile336H'}],
#     'headline': {'main': 'Sanford Sylvan, Baritone Who Created Major Opera Roles, Dies at 65',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Sanford Sylvan, 65, Baritone Who Created Major Opera Roles',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'persons',
#       'value': 'Sylvan, Sanford',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'Deaths (Obituaries)',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Opera', 'rank': 3, 'major': 'N'},
#      {'name': 'subject', 'value': 'Classical Music', 'rank': 4, 'major': 'N'},
#      {'name': 'persons',
#       'value': 'Adams, John (1947- )',
#       'rank': 5,
#       'major': 'N'},
#      {'name': 'persons', 'value': 'Sellars, Peter', 'rank': 6, 'major': 'N'},
#      {'name': 'creative_works',
#       'value': 'Nixon in China (Opera)',
#       'rank': 7,
#       'major': 'N'},
#      {'name': 'creative_works',
#       'value': 'The Death of Klinghoffer (Opera)',
#       'rank': 8,
#       'major': 'N'}],
#     'pub_date': '2019-02-02T00:20:59+0000',
#     'document_type': 'article',
#     'news_desk': 'Culture',
#     'section_name': 'Obituaries',
#     'byline': {'original': 'By ZACHARY WOOLFE',
#      'person': [{'firstname': 'Zachary',
#        'middlename': None,
#        'lastname': 'WOOLFE',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'Obituary (Obit)',
#     '_id': '5c54e28e3a125f5075c07a78',
#     'word_count': 1089,
#     'score': 0.0,
#     'uri': 'nyt://article/53ea5aa3-0bd2-50bd-ba1a-10b4b5ba27b1'}],
#   'meta': {'hits': 50, 'offset': 10, 'time': 43}}}

# %% [markdown]
# That looks intimidating! But it's really just a big dictionary. Let's see what keys we got in there.

# %%
# Extract keys 

data.keys()
# Out:
# dict_keys(['status', 'copyright', 'response'])

# %%
# This is boring

data['status']
# Out:
# 'OK'

# %%
# So is this

data['copyright']
# Out:
# 'Copyright (c) 2019 The New York Times Company. All Rights Reserved.'

# %%
# this is what we want!
# data['response']

# %%
data['response'].keys()
# Out:
# dict_keys(['docs', 'meta'])

# %%
data['response']['meta'].keys()
# Out:
# dict_keys(['hits', 'offset', 'time'])

# %%
data['response']['meta']['hits'] # Number of hits
# Out:
# 50

# %%
# data['response']['docs']
type(data['response']['docs'])
# Out:
# list

# %% [markdown]
# That looks what we want! Let's put that in it's own variable.

# %%
docs = data['response']['docs']

# %%
docs[1]
# Out:
# {'web_url': 'https://www.nytimes.com/2019/01/10/arts/music/rat-boy-internationally-unknown.html',
#  'snippet': 'The 22-year-old English musician Jordan Cardy sends up authority and celebrates slackerdom in songs that combine the energy of punk with the storytelling of hip-hop.',
#  'lead_paragraph': 'The 22-year-old English musician Jordan Cardy sends up authority and celebrates slackerdom in songs that combine the energy of punk with the storytelling of hip-hop.',
#  'print_page': '16',
#  'blog': {},
#  'source': 'The New York Times',
#  'multimedia': [{'rank': 0,
#    'subtype': 'xlarge',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/merlin_148718151_8fa1d02f-224d-4e88-8d9c-71a714512b0c-articleLarge.jpg',
#    'height': 480,
#    'width': 600,
#    'legacy': {'xlarge': 'images/2019/01/13/arts/13ratboy2/merlin_148718151_8fa1d02f-224d-4e88-8d9c-71a714512b0c-articleLarge.jpg',
#     'xlargewidth': 600,
#     'xlargeheight': 480},
#    'subType': 'xlarge',
#    'crop_name': 'articleLarge'},
#   {'rank': 0,
#    'subtype': 'wide',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-thumbWide-v2.jpg',
#    'height': 126,
#    'width': 190,
#    'legacy': {'wide': 'images/2019/01/13/arts/13ratboy2/13ratboy2-thumbWide-v2.jpg',
#     'widewidth': 190,
#     'wideheight': 126},
#    'subType': 'wide',
#    'crop_name': 'thumbWide'},
#   {'rank': 0,
#    'subtype': 'thumbnail',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-thumbStandard.jpg',
#    'height': 75,
#    'width': 75,
#    'legacy': {'thumbnail': 'images/2019/01/13/arts/13ratboy2/13ratboy2-thumbStandard.jpg',
#     'thumbnailwidth': 75,
#     'thumbnailheight': 75},
#    'subType': 'thumbnail',
#    'crop_name': 'thumbStandard'},
#   {'rank': 0,
#    'subtype': 'articleInline',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/merlin_148718151_8fa1d02f-224d-4e88-8d9c-71a714512b0c-articleInline.jpg',
#    'height': 152,
#    'width': 190,
#    'legacy': {},
#    'subType': 'articleInline',
#    'crop_name': 'articleInline'},
#   {'rank': 0,
#    'subtype': 'blog225',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/merlin_148718151_8fa1d02f-224d-4e88-8d9c-71a714512b0c-blog225.jpg',
#    'height': 180,
#    'width': 225,
#    'legacy': {},
#    'subType': 'blog225',
#    'crop_name': 'blog225'},
#   {'rank': 0,
#    'subtype': 'blog427',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/merlin_148718151_8fa1d02f-224d-4e88-8d9c-71a714512b0c-blog427.jpg',
#    'height': 342,
#    'width': 427,
#    'legacy': {},
#    'subType': 'blog427',
#    'crop_name': 'blog427'},
#   {'rank': 0,
#    'subtype': 'blog480',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/merlin_148718151_8fa1d02f-224d-4e88-8d9c-71a714512b0c-blog480.jpg',
#    'height': 384,
#    'width': 480,
#    'legacy': {},
#    'subType': 'blog480',
#    'crop_name': 'blog480'},
#   {'rank': 0,
#    'subtype': 'blog533',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/merlin_148718151_8fa1d02f-224d-4e88-8d9c-71a714512b0c-blog533.jpg',
#    'height': 426,
#    'width': 533,
#    'legacy': {},
#    'subType': 'blog533',
#    'crop_name': 'blog533'},
#   {'rank': 0,
#    'subtype': 'blogSmallInline',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/merlin_148718151_8fa1d02f-224d-4e88-8d9c-71a714512b0c-blogSmallInline.jpg',
#    'height': 121,
#    'width': 151,
#    'legacy': {},
#    'subType': 'blogSmallInline',
#    'crop_name': 'blogSmallInline'},
#   {'rank': 0,
#    'subtype': 'blogSmallThumb',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-blogSmallThumb.jpg',
#    'height': 50,
#    'width': 50,
#    'legacy': {},
#    'subType': 'blogSmallThumb',
#    'crop_name': 'blogSmallThumb'},
#   {'rank': 0,
#    'subtype': 'facebookJumbo',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-facebookJumbo.jpg',
#    'height': 550,
#    'width': 1050,
#    'legacy': {},
#    'subType': 'facebookJumbo',
#    'crop_name': 'facebookJumbo'},
#   {'rank': 0,
#    'subtype': 'filmstrip',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-filmstrip.jpg',
#    'height': 190,
#    'width': 190,
#    'legacy': {},
#    'subType': 'filmstrip',
#    'crop_name': 'filmstrip'},
#   {'rank': 0,
#    'subtype': 'hpLarge',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-hpLarge.jpg',
#    'height': 287,
#    'width': 511,
#    'legacy': {},
#    'subType': 'hpLarge',
#    'crop_name': 'hpLarge'},
#   {'rank': 0,
#    'subtype': 'hpSmall',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/merlin_148718151_8fa1d02f-224d-4e88-8d9c-71a714512b0c-hpSmall.jpg',
#    'height': 130,
#    'width': 163,
#    'legacy': {},
#    'subType': 'hpSmall',
#    'crop_name': 'hpSmall'},
#   {'rank': 0,
#    'subtype': 'jumbo',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/merlin_148718151_8fa1d02f-224d-4e88-8d9c-71a714512b0c-jumbo.jpg',
#    'height': 819,
#    'width': 1024,
#    'legacy': {},
#    'subType': 'jumbo',
#    'crop_name': 'jumbo'},
#   {'rank': 0,
#    'subtype': 'largeHorizontal375',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-largeHorizontal375-v2.jpg',
#    'height': 250,
#    'width': 375,
#    'legacy': {},
#    'subType': 'largeHorizontal375',
#    'crop_name': 'largeHorizontal375'},
#   {'rank': 0,
#    'subtype': 'largeHorizontalJumbo',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-largeHorizontalJumbo-v2.jpg',
#    'height': 683,
#    'width': 1024,
#    'legacy': {},
#    'subType': 'largeHorizontalJumbo',
#    'crop_name': 'largeHorizontalJumbo'},
#   {'rank': 0,
#    'subtype': 'largeWidescreen573',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-largeWidescreen573.jpg',
#    'height': 322,
#    'width': 573,
#    'legacy': {},
#    'subType': 'largeWidescreen573',
#    'crop_name': 'largeWidescreen573'},
#   {'rank': 0,
#    'subtype': 'largeWidescreen1050',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-largeWidescreen1050.jpg',
#    'height': 590,
#    'width': 1050,
#    'legacy': {},
#    'subType': 'largeWidescreen1050',
#    'crop_name': 'largeWidescreen1050'},
#   {'rank': 0,
#    'subtype': 'master1050',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/merlin_148718151_8fa1d02f-224d-4e88-8d9c-71a714512b0c-master1050.jpg',
#    'height': 840,
#    'width': 1050,
#    'legacy': {},
#    'subType': 'master1050',
#    'crop_name': 'master1050'},
#   {'rank': 0,
#    'subtype': 'master180',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/merlin_148718151_8fa1d02f-224d-4e88-8d9c-71a714512b0c-master180.jpg',
#    'height': 144,
#    'width': 180,
#    'legacy': {},
#    'subType': 'master180',
#    'crop_name': 'master180'},
#   {'rank': 0,
#    'subtype': 'master315',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/merlin_148718151_8fa1d02f-224d-4e88-8d9c-71a714512b0c-master315.jpg',
#    'height': 252,
#    'width': 315,
#    'legacy': {},
#    'subType': 'master315',
#    'crop_name': 'master315'},
#   {'rank': 0,
#    'subtype': 'master495',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/merlin_148718151_8fa1d02f-224d-4e88-8d9c-71a714512b0c-master495.jpg',
#    'height': 396,
#    'width': 495,
#    'legacy': {},
#    'subType': 'master495',
#    'crop_name': 'master495'},
#   {'rank': 0,
#    'subtype': 'master768',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/merlin_148718151_8fa1d02f-224d-4e88-8d9c-71a714512b0c-master768.jpg',
#    'height': 614,
#    'width': 768,
#    'legacy': {},
#    'subType': 'master768',
#    'crop_name': 'master768'},
#   {'rank': 0,
#    'subtype': 'master675',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/merlin_148718151_8fa1d02f-224d-4e88-8d9c-71a714512b0c-master675.jpg',
#    'height': 540,
#    'width': 675,
#    'legacy': {},
#    'subType': 'master675',
#    'crop_name': 'master675'},
#   {'rank': 0,
#    'subtype': 'mediumFlexible177',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/merlin_148718151_8fa1d02f-224d-4e88-8d9c-71a714512b0c-mediumFlexible177.jpg',
#    'height': 142,
#    'width': 177,
#    'legacy': {},
#    'subType': 'mediumFlexible177',
#    'crop_name': 'mediumFlexible177'},
#   {'rank': 0,
#    'subtype': 'mediumSquare149',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-mediumSquare149.jpg',
#    'height': 149,
#    'width': 149,
#    'legacy': {},
#    'subType': 'mediumSquare149',
#    'crop_name': 'mediumSquare149'},
#   {'rank': 0,
#    'subtype': 'mediumThreeByTwo210',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-mediumThreeByTwo210-v2.jpg',
#    'height': 140,
#    'width': 210,
#    'legacy': {},
#    'subType': 'mediumThreeByTwo210',
#    'crop_name': 'mediumThreeByTwo210'},
#   {'rank': 0,
#    'subtype': 'mediumThreeByTwo225',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-mediumThreeByTwo225-v2.jpg',
#    'height': 150,
#    'width': 225,
#    'legacy': {},
#    'subType': 'mediumThreeByTwo225',
#    'crop_name': 'mediumThreeByTwo225'},
#   {'rank': 0,
#    'subtype': 'mediumThreeByTwo440',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-mediumThreeByTwo440-v2.jpg',
#    'height': 293,
#    'width': 440,
#    'legacy': {},
#    'subType': 'mediumThreeByTwo440',
#    'crop_name': 'mediumThreeByTwo440'},
#   {'rank': 0,
#    'subtype': 'mediumThreeByTwo378',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-mediumThreeByTwo378-v2.jpg',
#    'height': 252,
#    'width': 378,
#    'legacy': {},
#    'subType': 'mediumThreeByTwo378',
#    'crop_name': 'mediumThreeByTwo378'},
#   {'rank': 0,
#    'subtype': 'mediumThreeByTwo252',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-mediumThreeByTwo252-v2.jpg',
#    'height': 168,
#    'width': 252,
#    'legacy': {},
#    'subType': 'mediumThreeByTwo252',
#    'crop_name': 'mediumThreeByTwo252'},
#   {'rank': 0,
#    'subtype': 'miniMoth',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-miniMoth.jpg',
#    'height': 70,
#    'width': 151,
#    'legacy': {},
#    'subType': 'miniMoth',
#    'crop_name': 'miniMoth'},
#   {'rank': 0,
#    'subtype': 'moth',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-moth.jpg',
#    'height': 151,
#    'width': 151,
#    'legacy': {},
#    'subType': 'moth',
#    'crop_name': 'moth'},
#   {'rank': 0,
#    'subtype': 'popup',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/merlin_148718151_8fa1d02f-224d-4e88-8d9c-71a714512b0c-popup.jpg',
#    'height': 500,
#    'width': 625,
#    'legacy': {},
#    'subType': 'popup',
#    'crop_name': 'popup'},
#   {'rank': 0,
#    'subtype': 'sfSpan',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-sfSpan-v2.jpg',
#    'height': 263,
#    'width': 395,
#    'legacy': {},
#    'subType': 'sfSpan',
#    'crop_name': 'sfSpan'},
#   {'rank': 0,
#    'subtype': 'slide',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/merlin_148718151_8fa1d02f-224d-4e88-8d9c-71a714512b0c-slide.jpg',
#    'height': 480,
#    'width': 600,
#    'legacy': {},
#    'subType': 'slide',
#    'crop_name': 'slide'},
#   {'rank': 0,
#    'subtype': 'smallSquare168',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-smallSquare168.jpg',
#    'height': 168,
#    'width': 168,
#    'legacy': {},
#    'subType': 'smallSquare168',
#    'crop_name': 'smallSquare168'},
#   {'rank': 0,
#    'subtype': 'smallSquare252',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-smallSquare252.jpg',
#    'height': 252,
#    'width': 252,
#    'legacy': {},
#    'subType': 'smallSquare252',
#    'crop_name': 'smallSquare252'},
#   {'rank': 0,
#    'subtype': 'square320',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-square320.jpg',
#    'height': 320,
#    'width': 320,
#    'legacy': {},
#    'subType': 'square320',
#    'crop_name': 'square320'},
#   {'rank': 0,
#    'subtype': 'square640',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-square640.jpg',
#    'height': 640,
#    'width': 640,
#    'legacy': {},
#    'subType': 'square640',
#    'crop_name': 'square640'},
#   {'rank': 0,
#    'subtype': 'superJumbo',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/merlin_148718151_8fa1d02f-224d-4e88-8d9c-71a714512b0c-superJumbo.jpg',
#    'height': 1638,
#    'width': 2048,
#    'legacy': {},
#    'subType': 'superJumbo',
#    'crop_name': 'superJumbo'},
#   {'rank': 0,
#    'subtype': 'thumbLarge',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-thumbLarge.jpg',
#    'height': 150,
#    'width': 150,
#    'legacy': {},
#    'subType': 'thumbLarge',
#    'crop_name': 'thumbLarge'},
#   {'rank': 0,
#    'subtype': 'tmagArticle',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/merlin_148718151_8fa1d02f-224d-4e88-8d9c-71a714512b0c-tmagArticle.jpg',
#    'height': 474,
#    'width': 592,
#    'legacy': {},
#    'subType': 'tmagArticle',
#    'crop_name': 'tmagArticle'},
#   {'rank': 0,
#    'subtype': 'tmagSF',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/merlin_148718151_8fa1d02f-224d-4e88-8d9c-71a714512b0c-tmagSF.jpg',
#    'height': 290,
#    'width': 362,
#    'legacy': {},
#    'subType': 'tmagSF',
#    'crop_name': 'tmagSF'},
#   {'rank': 0,
#    'subtype': 'verticalTwoByThree735',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-verticalTwoByThree735.jpg',
#    'height': 1103,
#    'width': 735,
#    'legacy': {},
#    'subType': 'verticalTwoByThree735',
#    'crop_name': 'verticalTwoByThree735'},
#   {'rank': 0,
#    'subtype': 'videoFifteenBySeven1305',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-videoFifteenBySeven1305.jpg',
#    'height': 609,
#    'width': 1305,
#    'legacy': {},
#    'subType': 'videoFifteenBySeven1305',
#    'crop_name': 'videoFifteenBySeven1305'},
#   {'rank': 0,
#    'subtype': 'videoFifteenBySeven2610',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-videoFifteenBySeven2610.jpg',
#    'height': 1218,
#    'width': 2610,
#    'legacy': {},
#    'subType': 'videoFifteenBySeven2610',
#    'crop_name': 'videoFifteenBySeven2610'},
#   {'rank': 0,
#    'subtype': 'videoHpMedium',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-videoHpMedium.jpg',
#    'height': 211,
#    'width': 375,
#    'legacy': {},
#    'subType': 'videoHpMedium',
#    'crop_name': 'videoHpMedium'},
#   {'rank': 0,
#    'subtype': 'videoLarge',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-videoLarge-v2.jpg',
#    'height': 507,
#    'width': 768,
#    'legacy': {},
#    'subType': 'videoLarge',
#    'crop_name': 'videoLarge'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNine1050',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-videoSixteenByNine1050.jpg',
#    'height': 591,
#    'width': 1050,
#    'legacy': {},
#    'subType': 'videoSixteenByNine1050',
#    'crop_name': 'videoSixteenByNine1050'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNine150',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-videoSixteenByNine150.jpg',
#    'height': 84,
#    'width': 150,
#    'legacy': {},
#    'subType': 'videoSixteenByNine150',
#    'crop_name': 'videoSixteenByNine150'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNine225',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-videoSixteenByNine225.jpg',
#    'height': 126,
#    'width': 225,
#    'legacy': {},
#    'subType': 'videoSixteenByNine225',
#    'crop_name': 'videoSixteenByNine225'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNine3000',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-videoSixteenByNine3000.jpg',
#    'height': 1687,
#    'width': 3000,
#    'legacy': {},
#    'subType': 'videoSixteenByNine3000',
#    'crop_name': 'videoSixteenByNine3000'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNine310',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-videoSixteenByNine310.jpg',
#    'height': 174,
#    'width': 310,
#    'legacy': {},
#    'subType': 'videoSixteenByNine310',
#    'crop_name': 'videoSixteenByNine310'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNine390',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-videoSixteenByNine390.jpg',
#    'height': 219,
#    'width': 390,
#    'legacy': {},
#    'subType': 'videoSixteenByNine390',
#    'crop_name': 'videoSixteenByNine390'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNine480',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-videoSixteenByNine480.jpg',
#    'height': 270,
#    'width': 480,
#    'legacy': {},
#    'subType': 'videoSixteenByNine480',
#    'crop_name': 'videoSixteenByNine480'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNine495',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-videoSixteenByNine495.jpg',
#    'height': 278,
#    'width': 495,
#    'legacy': {},
#    'subType': 'videoSixteenByNine495',
#    'crop_name': 'videoSixteenByNine495'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNine540',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-videoSixteenByNine540.jpg',
#    'height': 304,
#    'width': 540,
#    'legacy': {},
#    'subType': 'videoSixteenByNine540',
#    'crop_name': 'videoSixteenByNine540'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNine600',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-videoSixteenByNine600.jpg',
#    'height': 338,
#    'width': 600,
#    'legacy': {},
#    'subType': 'videoSixteenByNine600',
#    'crop_name': 'videoSixteenByNine600'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNine768',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-videoSixteenByNine768.jpg',
#    'height': 432,
#    'width': 768,
#    'legacy': {},
#    'subType': 'videoSixteenByNine768',
#    'crop_name': 'videoSixteenByNine768'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNine96',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-videoSixteenByNine96.jpg',
#    'height': 54,
#    'width': 96,
#    'legacy': {},
#    'subType': 'videoSixteenByNine96',
#    'crop_name': 'videoSixteenByNine96'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNineJumbo1600',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-videoSixteenByNineJumbo1600.jpg',
#    'height': 900,
#    'width': 1600,
#    'legacy': {},
#    'subType': 'videoSixteenByNineJumbo1600',
#    'crop_name': 'videoSixteenByNineJumbo1600'},
#   {'rank': 0,
#    'subtype': 'videoSmall',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-videoSmall.jpg',
#    'height': 281,
#    'width': 500,
#    'legacy': {},
#    'subType': 'videoSmall',
#    'crop_name': 'videoSmall'},
#   {'rank': 0,
#    'subtype': 'videoThumb',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-videoThumb-v2.jpg',
#    'height': 50,
#    'width': 75,
#    'legacy': {},
#    'subType': 'videoThumb',
#    'crop_name': 'videoThumb'},
#   {'rank': 0,
#    'subtype': 'watch268',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-watch268.jpg',
#    'height': 303,
#    'width': 272,
#    'legacy': {},
#    'subType': 'watch268',
#    'crop_name': 'watch268'},
#   {'rank': 0,
#    'subtype': 'watch308',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-watch308.jpg',
#    'height': 348,
#    'width': 312,
#    'legacy': {},
#    'subType': 'watch308',
#    'crop_name': 'watch308'},
#   {'rank': 0,
#    'subtype': 'windowsTile336H',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/01/13/arts/13ratboy2/13ratboy2-windowsTile336H.jpg',
#    'height': 336,
#    'width': 694,
#    'legacy': {},
#    'subType': 'windowsTile336H',
#    'crop_name': 'windowsTile336H'}],
#  'headline': {'main': 'The Dream of the ’90s Is Alive in Rat Boy’s Punk Rock',
#   'kicker': None,
#   'content_kicker': None,
#   'print_headline': 'Tales of Slackerdom With a ’90s Polish',
#   'name': None,
#   'seo': None,
#   'sub': None},
#  'keywords': [{'name': 'subject',
#    'value': 'Pop and Rock Music',
#    'rank': 1,
#    'major': 'N'},
#   {'name': 'persons',
#    'value': 'Cardy, Jordan (Rat Boy)',
#    'rank': 2,
#    'major': 'N'},
#   {'name': 'creative_works',
#    'value': 'Internationally Unknown (Album)',
#    'rank': 3,
#    'major': 'N'}],
#  'pub_date': '2019-01-10T14:56:23+0000',
#  'document_type': 'article',
#  'news_desk': 'Arts&Leisure',
#  'section_name': 'Arts',
#  'subsectoinName': 'Music',
#  'byline': {'original': 'By JON CARAMANICA',
#   'person': [{'firstname': 'Jon',
#     'middlename': None,
#     'lastname': 'CARAMANICA',
#     'qualifier': None,
#     'title': None,
#     'role': 'reported',
#     'organization': '',
#     'rank': 1}],
#   'organization': None},
#  'type_of_material': 'News',
#  '_id': '5c375d1d3a125f5075c03bcc',
#  'word_count': 1608,
#  'score': 0.0,
#  'uri': 'nyt://article/9b707629-2a34-509d-90b9-249eccc5fade'}

# %% [markdown]
# ## 3. Putting everything together to get all the articles.

# %% [markdown]
# That's great. But we only have 10 items. The original response said we had 50 hits! Which means we have to make 50/10, or 5 requests to get them all.*
#
# * In general, most free APIs have limits on how often you can "call" them, i.e., how many requests you can send. For the NYT, the daily limit is 1000, and you are limited to 5 calls/sec. At first, this might sound like plenty--but in general, it's not. You'll want to be creative with your search terms and date restrictions to ensure that you have a manageable number of calls to the API.
#
# * Sounds like a job for a loop!
#
# But first, let's review what we've done so far.

# %%
# set key
key="lJWFqmFXKLE8yoxN95xLjnyqMFk67a5I"

# set base url
base_url="http://api.nytimes.com/svc/search/v2/articlesearch"

# set response format
response_format=".json"

# set search parameters
search_params = {"q":"Prince music",
                 "api-key":key,
                 "begin_date": "20190101",
                 "end_date": "20191231"}

# make request
rr = requests.get(base_url + response_format, params = search_params)
    
# convert to a dictionary
data = json.loads(rr.text)
    
# get number of hits
hits = data['response']['meta']['hits']
print("number of hits: " + str(hits))
    
# get number of pages
# math.ceil(x) Return the ceiling of x as a float
pages = int(math.ceil(hits/10))
# Out:
# number of hits: 50

# %%
# make an empty list where we'll hold all of our docs for every page
all_docs = [] 
    
# now we're ready to loop through the pages
for i in range(pages):
    print("collecting page " + str(i))
        
    # set the page parameter
    search_params['page'] = i
        
    # make request
    rr = requests.get(base_url + response_format, params = search_params)
    
    # get text and convert to a dictionary
    data = json.loads(rr.text)
        
    # get just the docs
    docs = data['response']['docs']
        
    # add those docs to the big list
    all_docs = all_docs + docs # or you can do all_docs += docs
# Out:
# collecting page 0
# collecting page 1
# collecting page 2
# collecting page 3
# collecting page 4

# %%
print(data)
# Out:
# {'status': 'OK', 'copyright': 'Copyright (c) 2019 The New York Times Company. All Rights Reserved.', 'response': {'docs': [{'web_url': 'https://www.nytimes.com/2019/02/27/fashion/weddings/taylor-swift-surprises-a-couple-again.html', 'snippet': 'An Oscar weekend to remember: These two and their guests got a live performance of “King of My Heart” at their engagement party.', 'lead_paragraph': 'An Oscar weekend to remember: These two and their guests got a live performance of “King of My Heart” at their engagement party.', 'blog': {}, 'source': 'The New York Times', 'multimedia': [{'rank': 0, 'subtype': 'xlarge', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2019/02/27/fashion/weddings/27doozy1/27doozy1-articleLarge-v2.jpg', 'height': 400, 'width': 600, 'legacy': {'xlarge': 'images/2019/02/27/fashion/weddings/27doozy1/27doozy1-articleLarge-v2.jpg', 'xlargewidth': 600, 'xlargeheight': 400}, 'subType': 'xlarge', 'crop_name': 'articleLarge'}, {'rank': 0, 'subtype': 'wide', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2019/02/27/fashion/weddings/27doozy1/27doozy1-thumbWide-v3.jpg', 'height': 126, 'width': 190, 'legacy': {'wide': 'images/2019/02/27/fashion/weddings/27doozy1/27doozy1-thumbWide-v3.jpg', 'widewidth': 190, 'wideheight': 126}, 'subType': 'wide', 'crop_name': 'thumbWide'}, {'rank': 0, 'subtype': 'thumbnail', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2019/02/27/fashion/weddings/27doozy1/27doozy1-thumbStandard-v3.jpg', 'height': 75, 'width': 75, 'legacy': {'thumbnail': 'images/2019/02/27/fashion/weddings/27doozy1/27doozy1-thumbStandard-v3.jpg', 'thumbnailwidth': 75, 'thumbnailheight': 75}, 'subType': 'thumbnail', 'crop_name': 'thumbStandard'}, {'rank': 0, 'subtype': 'articleInline', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2019/02/27/fashion/weddings/27doozy1/27doozy1-articleInline-v3.jpg', 'height': 127, 'width': 190, 'legacy': {}, 'subType': 'articleInline', 'crop_name': 'articleInline'}, {'rank': 0, 'subtype': 'blog225', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2019/02/27/fashion/weddings/27doozy1/27doozy1-blog225-v2.jpg', 'height': 150, 'width': 225, 'legacy': {}, 'subType': 'blog225', 'crop_name': 'blog225'}, {'rank': 0, 'subtype': 'blog427', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2019/02/27/fashion/weddings/27doozy1/27doozy1-blog427-v2.jpg', 'height': 285, 'width': 427, 'legacy': {}, 'subType': 'blog427', 'crop_name': 'blog427'}, {'rank': 0, 'subtype': 'blog480', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2019/02/27/fashion/weddings/27doozy1/27doozy1-blog480-v2.jpg', 'height': 320, 'width': 480, 'legacy': {}, 'subType': 'blog480', 'crop_name': 'blog480'}, {'rank': 0, 'subtype': 'blog533', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2019/02/27/fashion/weddings/27doozy1/27doozy1-blog533-v2.jpg', 'height': 355, 'width': 533, 'legacy': {}, 'subType': 'blog533', 'crop_name': 'blog533'}, {'rank': 0, 'subtype': 'blogSmallInline', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2019/02/27/fashion/weddings/27doozy1/27doozy1-blogSmallInline-v3.jpg', 'height': 101, 'width': 151, 'legacy': {}, 'subType': 'blogSmallInline', 'crop_name': 'blogSmallInline'}, {'rank': 0, 'subtype': 'blogSmallThumb', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2019/02/27/fashion/weddings/27doozy1/27doozy1-blogSmallThumb-v3.jpg', 'height': 50, 'width': 50, 'legacy': {}, 'subType': 'blogSmallThumb', 'crop_name': 'blogSmallThumb'}, {'rank': 0, 'subtype': 'facebookJumbo', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2019/02/27/fashion/weddings/27doozy1/27doozy1-facebookJumbo-v3.jpg', 'height': 550, 'width': 1050, 'legacy': {}, 'subType': 'facebookJumbo', 'crop_name': 'facebookJumbo'}, {'rank': 0, 'subtype': 'filmstrip', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2019/02/27/fashion/weddings/27doozy1/27do ...

# %%
len(all_docs)
# Out:
# 50

# %% [markdown]
# ### Challenge 3: Make a function
#
# Turn the code above into a function that inputs a search term, and returns all the documents containing that search term in 2014.

# %%
def apisearch(q, begin):
    # set key
    key="c98c46b9278b4f4e98acb812ec3d9dbb"
    # set base url
    base_url="http://api.nytimes.com/svc/search/v2/articlesearch"
    # set response format
    response_format=".json" 
    search_params = {"q": q,
                 "begin_date": begin,
                 "end_date": "20141231",
                 "page": "1",
                 "api-key":key}  
    # make request
    r = requests.get(base_url+response_format, params=search_params)
    print(r.url)

# %%
apisearch("Clinton", "20140101")
# Out:
# http://api.nytimes.com/svc/search/v2/articlesearch.json?q=Clinton&begin_date=20140101&end_date=20141231&page=1&api-key=c98c46b9278b4f4e98acb812ec3d9dbb

# %% [markdown]
# ## 4. Formatting and Exporting
#
# Let's take another look at one of these documents.

# %%
all_docs[0]
# Out:
# {'web_url': 'https://www.nytimes.com/aponline/2019/03/01/arts/ap-us-people-manuela-testolini.html',
#  'snippet': 'Andra Day, Dave Stewart of the Eurythmics and Philip Bailey and Verdine White of Earth, Wind &amp; Fire will perform during a fundraising gala honoring Prince to benefit the foundation of his second wife, Manuela Testolini.',
#  'lead_paragraph': 'Andra Day, Dave Stewart of the Eurythmics and Philip Bailey and Verdine White of Earth, Wind &amp; Fire will perform during a fundraising gala honoring Prince to benefit the foundation of his second wife, Manuela Testolini.',
#  'blog': {},
#  'source': 'AP',
#  'multimedia': [],
#  'headline': {'main': "Foundation of Prince's Second Wife to Honor Him at Gala",
#   'kicker': None,
#   'content_kicker': None,
#   'print_headline': "Foundation of Prince's Second Wife to Honor Him at Gala",
#   'name': None,
#   'seo': None,
#   'sub': None},
#  'keywords': [],
#  'pub_date': '2019-03-01T22:05:08+0000',
#  'document_type': 'article',
#  'news_desk': 'None',
#  'section_name': 'Arts',
#  'byline': {'original': 'By THE ASSOCIATED PRESS',
#   'person': [],
#   'organization': 'THE ASSOCIATED PRESS'},
#  'type_of_material': 'News',
#  '_id': '5c79acee49f0eacbf105af2d',
#  'word_count': 339,
#  'score': 0.0,
#  'uri': 'nyt://article/d0836fb2-03f8-506a-b99b-78ae8820615e'}

# %% [markdown]
# This is all great, but it's pretty messy. What we’d really like to to have, eventually, is a CSV, with each row representing an article, and each column representing something about that article (header, date, etc). As we saw before, the best way to do this is to make a lsit of dictionaries, with each dictionary representing an article and each dictionary representing a field of metadata from that article (e.g. headline, date, etc.) We can do this with a custom function:

# %%
def format_articles(unformatted_docs):
    '''
    This function takes in a list of documents returned by the NYT api 
    and parses the documents into a list of dictionaries, 
    with 'id', 'header', and 'date' keys
    '''
    formatted = []
    for i in unformatted_docs:
        dic = {}
        dic['id'] = i['_id']
        dic['headline'] = i['headline']['main'].encode("utf8")
        dic['date'] = i['pub_date'][0:10] # cutting time of day.
        formatted.append(dic)
    return(formatted)

# %%
all_formatted = format_articles(all_docs)

# %%
all_formatted[:5]
# Out:
# [{'id': '5c79acee49f0eacbf105af2d',
#   'headline': b"Foundation of Prince's Second Wife to Honor Him at Gala",
#   'date': '2019-03-01'},
#  {'id': '5c7e8fda49f0eacbf105b6d4',
#   'headline': b'Queen Marks 50th Anniversary of Investiture of Son Charles as Prince of Wales',
#   'date': '2019-03-05'},
#  {'id': '5c2e85e53a125f5075c02bdf',
#   'headline': b'12 Pop, Rock and Jazz Concerts to Check Out in N.Y.C. This Weekend',
#   'date': '2019-01-03'},
#  {'id': '5c2fbcb23a125f5075c02e49',
#   'headline': b'New Year\xe2\x80\x99s Sounds: The Week in Classical Music',
#   'date': '2019-01-04'},
#  {'id': '5c6d176f3a125f5075c0a8b6',
#   'headline': b'Chaka Khan on Artistic Freedom, Her Side Hustles and Joni Mitchell',
#   'date': '2019-02-20'}]

# %% [markdown]
# ### Challenge 4: Export the data to a CSV.

# %%
## Import library csv 
import csv 

## Extract keys from the dictionary 
keys = all_formatted[0].keys() 

## Save the keys as a csv file
with open('article_API.csv', 'w') as output_file:
    # Maps Dictionaries onto Objects
    dict_writer = csv.DictWriter(f = output_file, fieldnames = keys)
    # Write rows with field names
    dict_writer.writeheader()
    # Write rows of data
    dict_writer.writerows(all_formatted)
