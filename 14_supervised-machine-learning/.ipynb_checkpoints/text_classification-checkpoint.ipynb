# %% [markdown]
# # Text classification

# %% [markdown]
# Text classification is a type of supervised machine learning. The workflow is as follows.
#
# - First, you prepapre hand-labeled outputs.
# - Then, preprocess the data and build and train a model based on it.
# - After done with the cross-validation, apply the model to the entire dataset.
#
# Note that this is a much simpilfied version of what I did for my disseratation chapter. Smaller data, and less explorations for features and algorithms.

# %% [markdown]
# ## Load libraries
#
# You don't need to load these many libraries.

# %%
# %matplotlib inline
import os
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import numpy as np # for large data 
import pandas as pd # for data manipulation and analysis
from subprocess import check_output
import matplotlib.pyplot as plt
import seaborn as sns
import gensim, nltk, re, string, xgboost, textblob, spacy

# nltk

from nltk import word_tokenize, sent_tokenize # for tokenization
from nltk.corpus import stopwords # for stop words

stop = stopwords.words('english')

from nltk.stem import WordNetLemmatizer # lemmatizer
from nltk.stem import LancasterStemmer, WordNetLemmatizer
from nltk import tokenize
from collections import Counter

import contractions
import inflect
from bs4 import BeautifulSoup

import unicodedata

from pattern.en import tag
from nltk.corpus import wordnet as wn

# models 

from sklearn import model_selection, preprocessing, linear_model, naive_bayes, metrics, svm
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer # for bag of words, tfidf 
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn import decomposition, ensemble 

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import SGDClassifier

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import RandomForestClassifier
sns.set()

from gensim.test.utils import common_texts, get_tmpfile
from gensim.models import Word2Vec # for word2vec

from keras.preprocessing import text, sequence 
from keras import layers, models, optimizers
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Load data

# %%
aa_newspapers = pd.read_csv("/home/jae/PS239T/14_supervised-machine-learning/data/african_american_newspapers.csv")

# %%
aa_newspapers
# Out:
#       Unnamed: 0                 author        date  \
# 0              1                    NaN  1968-11-23
# 1              2                    NaN  1968-11-13
# 2              3                    NaN  1968-11-13
# 3              4                    NaN  1968-12-18
# 4              5                    NaN  1968-12-28
# 5              6                    NaN  1968-12-18
# 6              7                    NaN  1968-10-09
# 7              8                    NaN  1968-10-31
# 8              9                    NaN  1968-09-11
# 9             10           Fleming, Tom  1968-11-23
# 10            11                    NaN  1968-11-20
# 11            12                    NaN  1968-12-04
# 12            13                    NaN  1968-10-16
# 13            14                    NaN  1968-12-28
# 14            15                    NaN  1968-12-21
# 15            16                    NaN  1968-11-23
# 16            17                    NaN  1968-09-25
# 17            18                    NaN  1968-10-30
# 18            19                    NaN  1968-10-23
# 19            20                    NaN  1968-11-23
# 20            21                    NaN  1968-10-30
# 21            22                    NaN  1968-11-13
# 22            23            Rowe, Billy  1968-11-06
# 23            24  Allen, William Duncan  1968-11-20
# 24            25                    NaN  1968-12-25
# 25            26                    NaN  1968-12-18
# 26            27             Ross, Anne  1968-12-14
# 27            28                    NaN  1968-11-25
# 28            29                    NaN  1968-10-16
# 29            30                    NaN  1968-12-26
# ...          ...                    ...         ...
# 978          979                    NaN  1981-01-21
# 979          980                    NaN  1981-02-15
# 980          981      Bresciani, Dennis  1981-01-14
# 981          982                    NaN  1981-01-26
# 982          983                    NaN  1981-02-03
# 983          984         McDonald, Newt  1981-02-01
# 984          985         McDaniel, Ruth  1981-01-26
# 985          986                    NaN  1981-02-22
# 986          987                    NaN  1981-01-11
# 987          988                    NaN  1981-01-09
# 988          989                    NaN  1981-02-03
# 989          990                    NaN  1981-03-18
# 990          991                    NaN  1981-02-20
# 991          992                    NaN  1981-01-06
# 992          993      Bresciani, Dennis  1981-03-04
# 993          994         Gereben, Janos  1981-02-05
# 994          995          Weekes, Berry  1981-02-20
# 995          996                    NaN  1981-02-19
# 996          997         Parker, Evelyn  1981-03-20
# 997          998                    NaN  1981-02-25
# 998          999             Hyman, Mac  1981-02-06
# 999         1000            Best, Harry  1981-02-15
# 1000        1001                    NaN  1981-01-26
# 1001        1002          Weekes, Berry  1981-03-13
# 1002        1003    Hasan, Imam Mustafa  1981-01-11
# 1003        1004                    NaN  1981-01-12
# 1004        1005      Bresciani, Dennis  1981-02-08
# 1005        1006         Wells, Eddye K  1981-03-18
# 1006        1007          Berkley, Gail  1981-02-01
# 1007        1008                    NaN  1981-03-15
#
#                                source  \
# 0            Sun Reporter (1968-1979)
# 1            Oakland Post (1968-1981)
# 2            Oakland Post (1968-1981)
# 3            Oakland Post (1968-1981)
# 4            Sun Reporter (1968-1979)
# 5            Oakland Post (1968-1981)
# 6            Oakland Post (1968-1981)
# 7     Sacramento Observer (1968-1975)
# 8            Oakland Post (1968-1981)
# 9            Sun Reporter (1968-1979)
# 10           Oakland Post (1968-1981)
# 11           Oakland Post (1968-1981)
# 12           Oakland Post (1968-1981)
# 13           Sun Reporter (1968-1979)
# 14           Sun Reporter (1968-1979)
# 15           Sun Reporter (1968-1979)
# 16           Oakland Post (1968-1981)
# 17           Oakland Post (1968-1981)
# 18           Oakland Post (1968-1981)
# 19           Sun Reporter (1968-1979)
# 20           Oakland Post (1968-1981)
# 21           Oakland Post (1968-1981)
# 22           Oakland Post (1968-1981)
# 23           Oakland Post (1968-1981)
# 24           Oakland Post (1968-1981)
# 25           Oakland Post (1968-1981)
# 26           Sun Reporter (1968-1979)
# 27           Oakland Post (1968-1981)
# 28           Oakland Post (1968-1981)
# 29    Sacramento Observer (1968-1975)
# ...                               ...
# 978          Oakland Post (1968-1981)
# 979          Oakland Post (1968-1981)
# 980          Oakland Post (1968-1981)
# 981          Oakland Post (1968-1981)
# 982          Oakland Post (1968-1981)
# 983          Oakland Post (1968-1981)
# 984          Oakland Post (1968-1981)
# 985          Oakland Post (1968-1981)
# 986          Oakland Post (1968-1981)
# 987          Oakland Post (1968-1981)
# 988          Oakland Post (1968-1981)
# 989          Oakland Post (1968-1981)
# 990          Oakland Post (1968-1981)
# 991          Oakland Post (1968-1981)
# 992          Oakland Post (1968-1981)
# 993          Oakland Post (1968-1981)
# 994          Oakland Post (1968-1981)
# 995          Oakland Post (1968-1981)
# 996          Oakland Post (1968-1981)
# 997          Oakland Post (1968-1981)
# 998          Oakland Post (1968-1981)
# 999          Oakland Post (1968-1981)
# 1000         Oakland Post (1968-1981)
# 1001         Oakland Post (1968-1981)
# 1002         Oakland Post (1968-1981)
# 1003         Oakland Post (1968-1981)
# 1004         Oakland Post (1968-1981)
# 1005         Oakland Post (1968-1981)
# 1006         Oakland Post (1968-1981)
# 1007         Oakland Post (1968-1981)
#
#                                                    text  year  \
# 0      Friday, Nov. 22, at 8 p.m. Rev. L. S. Rubin, ...  1968
# 1      "We have a large building, an ante bellum bui...  1968
# 2      KTVU's 'tele-voters' were back to being prett...  1968
# 3      WASHINGTON, D.C. -- Washington's appointed Ma...  1968
# 4      Spokesmen for the Congress of Racial Equality...  1968
# 5      The Lowell Junior High school fire that cause...  1968
# 6      SACRAMENTO -- One of the first Negro mayors i...  1968
# 7      Robert Weaver, head of the Department of Hous...  1968
# 8      The new Zellerbach Auditorium at the Universi...  1968
# 9      Three San Francisco police officers were shot...  1968
# 10     November 17th marked the 25th wedding anniver...  1968
# 11     Exceptional leadership potential has earned a...  1968
# 12     Robert L. Dixon, recently appointed Special M...  1968
# 13     A 53-year-old man was fatally gunned down by ...  1968
# 14     SWEET POTATO SOUFFLE2 cups mashed sweet potat...  1968
# 15     Two old friends got into an argument over a m...  1968
# 16     She sits in front of a stack of paper; someti...  1968
# 17     "Slow Dance on The Killpng Ground" is the Dia...  1968
# 18     Looking for a job?A Job-Finding Workshop has ...  1968
# 19     Funeral services for Mrs. Mary Breda were hel...  1968
# 20     American Negroes have produced significantly ...  1968
# 21     The San Francisco Redevelopment Agency and Ba...  1968
# 22     AUTHENTIC BUT NOT GUARANTEEDNew YORK -- CBS T...  1968
# 23     "Music Hath Charms to Soothe the Savage Breas...  1968
# 24     Panthers Submachine-gun Police Station, Arres...  1968
# 25     Tschaikowsky's "Nutcracker" ballet which has ...  1968
# 26     "I had a few apprehensions, as did my friends...  1968
# 27     LOS ANGELES -- (Special to The POST) -- Counc...  1968
# 28     GRANADA -- Jim Brown, former professional foo...  1968
# 29     Wouldn't it be nice to go out and wine and di...  1968
# ...                                                 ...   ...
# 978   ROASTED STUFFED PORK4 to 5 pound pork roast (a...  1981
# 979   Music has been an integral part of the human e...  1981
# 980   Oakland school chief Ruth Love has accepted an...  1981
# 981   Just when things were beginning to clear up in...  1981
# 982   Johnny McKeel doesn't feel like a hero and nei...  1981
# 983   If you paid for child care services during 198...  1981
# 984   Dear Ruth,I need a basic quick bread recipe wi...  1981
# 985   With the name Allah, the name of God most grac...  1981
# 986   A four-member ad hoc committee representing bl...  1981
# 987   Willie C. Brown. International Longshoreman an...  1981
# 988   A high-ranking army spokesman said Sunday Sout...  1981
# 989   Lent is a religious season observed in the Spr...  1981
# 990   SAN FRANCISCO (Special) -- On February 10 the ...  1981
# 991   Francesca Thompson, chairperson department of ...  1981
# 992   Although 78-year-old Eliza Ashley lives by her...  1981
# 993   There are two strangely similar movies in town...  1981
# 994   DOWN THE LAZY RIVER ... His voice is like a fi...  1981
# 995   OAKLAND. February 11, 1981--The Black Student ...  1981
# 996   "Once upon a midnight dreary."With these words...  1981
# 997   San Antonio Spurs' center George Johnson is fa...  1981
# 998   THE JOHN LUCAS CASE.....Make no mistake about ...  1981
# 999   In the San Francisco/Oakland Bay Area there ar...  1981
# 1000  Virginia M. King of N. Palm Beach, Florida, en...  1981
# 1001  THE FLYING FINS Finnair is inaugurating, a new...  1981
# 1002  (The third of a three part series)Greetings of...  1981
# 1003  The Black Democratic Clubs and Black political...  1981
# 1004  Deputy Superintendent Dr. Charles Mitchell is ...  1981
# 1005  MR. AND MRS. CHARLES BROOKS CELEBRATE 45th WED...  1981
# 1006  The seven directors of the East Bay Municipal ...  1981
# 1007  Gertrude Smith the 12th of 16 children was bor...  1981
#
#       linked_progress  linked_hurt
# 0                   0            0
# 1                   1            1
# 2                   0            1
# 3                   0            0
# 4                   1            0
# 5                   0            1
# 6                   1            0
# 7                   1            0
# 8                   0            0
# 9                   0            1
# 10                  0            0
# 11                  0            0
# 12                  1            0
# 13                  0            0
# 14                  0            0
# 15                  0            0
# 16                  1            0
# 17                  0            1
# 18                  1            0
# 19                  0            0
# 20                  1            0
# 21                  1            0
# 22                  1            0
# 23                  0            0
# 24                  0            1
# 25                  0            0
# 26                  0            0
# 27                  1            0
# 28                  1            1
# 29                  0            0
# ...               ...          ...
# 978                 0            0
# 979                 0            0
# 980                 1            0
# 981                 0            0
# 982                 0            0
# 983                 1            0
# 984                 0            0
# 985                 0            0
# 986                 1            0
# 987                 1            0
# 988                 0            1
# 989                 0            0
# 990                 0            0
# 991                 1            0
# 992                 0            0
# 993                 0            0
# 994                 0            0
# 995                 1            0
# 996                 0            0
# 997                 0            0
# 998                 0            0
# 999                 1            0
# 1000                0            0
# 1001                0            0
# 1002                0            0
# 1003                1            0
# 1004                0            0
# 1005                0            0
# 1006                0            1
# 1007                0            0
#
# [1008 rows x 8 columns]

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Remove special characters, punctuations, numbers, and whitespace

# %%
# sample

aa_newspapers['text'] = aa_newspapers['text'].str.replace('\n','', regex = True).str.replace(',','', regex = True).str.replace(':','', regex = True).str.replace('/','', regex = True)
aa_newspapers['text'] = aa_newspapers['text'].str.replace('\\','', regex = True).str.replace('-','', regex = True).str.replace('"','', regex = True)
aa_newspapers['text'] = aa_newspapers['text'].str.replace('\d+', '', regex = True) # remove numbers
aa_newspapers['text'] = aa_newspapers['text'].str.strip() # remove whitespace

# %%
aa_newspapers['text'][2]
# Out:
# "KTVU's 'televoters' were back to being pretty uptight this week.San Francisco's Mayor Alioto should not apologize to the Black Panthers for his remarks about the Sunday night bombings in the opinion of  percent.Teachers should not strike if violence is not curbed in high schools   percent to .Fiftythree percent did not agree with President Johnson's announcement on Vietnam; and  percent do not think the bombing halt will result in peace in Vietnam ... As a matter of fact you might say Don't give up the ship was the byword of viewers polled by Channel  in its weekly question and answer period.However the San FranciscoOakland TV station stressed the continuing nonscientific not necessarily representative of community opinion nature of its poll."

# %% [markdown]
# ### Lower case

# %%
aa_newspapers['text'] = aa_newspapers['text'].str.lower()

# %%
aa_newspapers['text'][2]
# Out:
# "ktvu's 'televoters' were back to being pretty uptight this week.san francisco's mayor alioto should not apologize to the black panthers for his remarks about the sunday night bombings in the opinion of  percent.teachers should not strike if violence is not curbed in high schools   percent to .fiftythree percent did not agree with president johnson's announcement on vietnam; and  percent do not think the bombing halt will result in peace in vietnam ... as a matter of fact you might say don't give up the ship was the byword of viewers polled by channel  in its weekly question and answer period.however the san franciscooakland tv station stressed the continuing nonscientific not necessarily representative of community opinion nature of its poll."

# %% [markdown]
# ## Classification

# %% [markdown]
# ### Extracting features
#
# We need to turn text into numerical vectors called features. There are various options to do so, ranging from simple bag of words to TF-IDF to word embeddings (e.g., word2vec). In this case, we try bag of words.
#
# I adapted some code from [here](https://link.springer.com/chapter/10.1007/978-1-4842-2388-8_4#Sec2).

# %%
## Extract features

# %%
vectorizer = CountVectorizer(
    min_df = 1,
    ngram_range = (1,2),
    max_features = 5000,
    binary = True)

# %%
def dtm_train(data, text, column, date):
    # Bag of words model
    
    features = vectorizer.fit_transform(data[text])
    
    response = data[column].values 

    # split into train/test datasets 

    X_train, X_test, y_train, y_test = train_test_split(features, response, 
                                                        test_size = 0.3,
                                                        random_state = 1234,
                                                        stratify = data[date])

    return(X_train, y_train, X_test, y_test)

# %%
# linked progress
aa_dtm_lp = dtm_train(aa_newspapers, 'text', 'linked_progress', 'year')
aa_X_train_lp = aa_dtm_lp[0]
aa_y_train_lp = aa_dtm_lp[1]
aa_X_test_lp = aa_dtm_lp[2]
aa_y_test_lp = aa_dtm_lp[3]

# linked hurt 
aa_dtm_lh = dtm_train(aa_newspapers, 'text', 'linked_hurt', 'year')
aa_X_train_lh = aa_dtm_lh[0]
aa_y_train_lh = aa_dtm_lh[1]
aa_X_test_lh = aa_dtm_lh[2]
aa_y_test_lh = aa_dtm_lh[3]

# %% [markdown]
# ### Training a model
#
# We build various models and test their performances using confusion matrix. Accuracy is the combination of true positives (1,1) and negatives (2,2).

# %%
# logistic regression
def fit_logistic_regression(X_train, y_train):
    model = LogisticRegression(max_iter = 4000)
    model.fit(X_train, y_train)
    return model

# random forest
def fit_random_forest(X_train, y_train):
    model = RandomForestClassifier(n_estimators = 200, max_depth = 3, random_state = 42)
    model.fit(X_train, y_train)
    return model 

# naive bayes
def fit_bayes(X_train, y_train):
    model = MultinomialNB()
    model.fit(X_train, y_train)
    return model

def test_model(model, X_train, y_train, X_test, y_test):
    y_pred = model.predict(X_test)
    print(confusion_matrix(y_test, y_pred))
    print('Accuracy: ', model.score(X_test, y_test))

# %%
## linked progress
aa_lp = fit_logistic_regression(aa_X_train_lp, aa_y_train_lp)
aa_lp_rf = fit_random_forest(aa_X_train_lp, aa_y_train_lp)
aa_lp_bayes = fit_bayes(aa_X_train_lp, aa_y_train_lp)

## linked hurt 
aa_lh = fit_logistic_regression(aa_X_train_lh, aa_y_train_lh)
aa_lh_rf = fit_random_forest(aa_X_train_lh, aa_y_train_lh)
aa_lh_bayes = fit_bayes(aa_X_train_lh, aa_y_train_lh)

# %% [markdown]
# #### Cross-validation check

# %%
# asian sample test 

## linked progress
print("linked progress")
test_model(aa_lp, aa_X_train_lp, aa_y_train_lp, aa_X_test_lp, aa_y_test_lp)
test_model(aa_lp_rf, aa_X_train_lp, aa_y_train_lp, aa_X_test_lp, aa_y_test_lp)
test_model(aa_lp_bayes, aa_X_train_lp, aa_y_train_lp, aa_X_test_lp, aa_y_test_lp)

## linked hurt
print("linked hurt")
test_model(aa_lh, aa_X_train_lh, aa_y_train_lh, aa_X_test_lh, aa_y_test_lh)
test_model(aa_lh_rf, aa_X_train_lh, aa_y_train_lh, aa_X_test_lh, aa_y_test_lh)
test_model(aa_lh_bayes, aa_X_train_lh, aa_y_train_lh, aa_X_test_lh, aa_y_test_lh)
# Out:
# linked progress
# [[206  18]
#  [ 53  26]]
# Accuracy:  0.7656765676567657
# [[224   0]
#  [ 79   0]]
# Accuracy:  0.7392739273927392
# [[166  58]
#  [ 22  57]]
# Accuracy:  0.735973597359736
# linked hurt
# [[241   5]
#  [ 36  21]]
# Accuracy:  0.8646864686468647
# [[246   0]
#  [ 57   0]]
# Accuracy:  0.8118811881188119
# [[213  33]
#  [ 10  47]]
# Accuracy:  0.858085808580858
